# %% [markdown]
# # Define configurations

# %%
user = 'participant2'
frequency = '15s' # 15min | 15s
dataset_type = '' # ''

if frequency == '15min':
    record_size_per_day = 96
elif frequency == '15s':
    record_size_per_day = 5760

# Columns to include    
if dataset_type == '':
    columns = [ 'timestamp', 'heart_rate', 'steps', 'stress_score',
            'awake', 'deep', 'light', 'rem', 'nonrem_total', 'total', 'nonrem_percentage', 'sleep_efficiency',
            'time_from_last_drug_taken', 'wearing_off' ]

metrics = {
    'balanced_accuracy': 'Bal. Acc.',
    'f1_score': 'F1 Score',
    'accuracy': 'Acc.',
    'precision': 'Precision',
    'sensitivity': 'Recall / Sn',
    'specificity': 'Sp',
    'auc': 'AUC'
}

# %% [markdown]
# # Preparation

# %% [markdown]
# ## Load libraries

# %%
from datetime import datetime
from datetime import timedelta
from typing import Union, Generator

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch
import warnings
from sklearn.exceptions import UndefinedMetricWarning, ConvergenceWarning

import sklearn
from photonai.base import Hyperpipe, PipelineElement, Stack, Switch
from photonai.optimization import FloatRange, IntegerRange, Categorical, BooleanSwitch, PhotonHyperparam
from photonai.optimization import Categorical as PhotonCategorical
from photonai.optimization import MinimumPerformanceConstraint, DummyPerformanceConstraint, BestPerformanceConstraint
from photonai.optimization.base_optimizer import PhotonSlaveOptimizer
from sklearn.model_selection import KFold, StratifiedKFold, TimeSeriesSplit, StratifiedShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from tabulate import tabulate

from skopt import Optimizer
from skopt.space import Real, Integer, Dimension
from skopt.space import Categorical as skoptCategorical
from photonai.photonlogger.logger import logger
from photonai.optimization.scikit_optimize.sk_opt import SkOptOptimizer

warnings.filterwarnings("ignore", category=UndefinedMetricWarning)
warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=Warning)
from photonai.base import Hyperpipe
from photonai.optimization import MinimumPerformanceConstraint
from photonai.photonlogger import logger

# %% [markdown]
# ## Load combined data

# %%
combined_data = pd.read_excel(f'./data/combined_data/{dataset_type}combined_data_{user}_{frequency}.xlsx',
                              index_col="timestamp",
                              usecols=columns,
                              engine='openpyxl')
if dataset_type == '':
    y = combined_data.loc[:, combined_data.columns == 'wearing_off'].values[:,0]
    X = combined_data.loc[:, columns[1:-1]]

# %% [markdown]
# ## Define Functions

# %%
# Show feature importances
def print_feature_importances(pipeline):
    output = ''
    if pipeline.optimum_pipe.feature_importances_ is None:
        output = 'Best Hyperparameter Configuration is a non-linear SVM, thus feature importances cannot be retrieved'
    else:
        output = 'Feature Importances using the Best Hyperparameter Config'
        if not [value.base_element.support_.tolist() for key, value in pipeline.optimum_pipe.elements if key == 'RFE']:
            if len(pipeline.optimum_pipe.feature_importances_) == 1:
                feature_importances = pipeline.optimum_pipe.feature_importances_[0]
            else:
                feature_importances = pipeline.optimum_pipe.feature_importances_
            output += '\n'
            output += tabulate(
                pd.DataFrame(
                    [np.around(feature_importances, decimals=4)],
                    columns=np.array(columns[1:-1])
                ).transpose().sort_values(by=[0], ascending=False, key=abs),
                tablefmt='psql', floatfmt=".4f", headers=['Features', 'Values']
            )
        else:
            mask = [value.base_element.support_.tolist() for key, value in pipeline.optimum_pipe.elements if key == 'RFE'][0]
            if len(pipeline.optimum_pipe.feature_importances_) == 1:
                feature_importances = pipeline.optimum_pipe.feature_importances_[0]
            else:
                feature_importances = pipeline.optimum_pipe.feature_importances_
            output += '\n'
            output += tabulate(
                pd.DataFrame(
                    [np.around(feature_importances, decimals=4)],
                    columns=np.array(columns[1:-1])[mask]
                ).transpose().sort_values(by=[0], ascending=False, key=abs),
                tablefmt='psql', floatfmt=".4f", headers=['Features', 'Values']
            )
    return output

# %%
def plot_cv_indices(cv, X, y, ax, n_splits=0, lw=20):
    """Create a sample plot for indices of a cross-validation object."""

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y)):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                    c=indices, marker='_', lw=lw, cmap=plt.cm.coolwarm,
                    vmin=-.2, vmax=1.2)

    n_splits = ii + 1

    # Plot the data classes and groups at the end
    ax.scatter(range(len(X)), [ii + 1.5] * len(X), c=y, marker='_', lw=lw, cmap=plt.cm.Paired)

    # Formatting
    yticklabels = list(range(n_splits)) + ['wearing-off']
    ax.set(yticks=np.arange(n_splits+1) + .5, yticklabels=yticklabels,
           xlabel='Records\'s Index', ylabel="Folds",
           ylim=[n_splits+1.2, -.2], xlim=[0, len(X)])
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)
    return ax

# %%
def plot_confusion_matrix_from_pipeline(pipeline):
    fig, ax = plt.subplots(figsize=(10, 10))
    cm = confusion_matrix(
        pipeline.results_handler.get_test_predictions()['y_true'],
        pipeline.results_handler.get_test_predictions()['y_pred'],
        labels=[0,1], normalize=None)
    ax = plt.subplot()
    sns.set(font_scale=3.0) # Adjust to fit
    sns.heatmap(cm, annot=True, ax=ax, cmap="Blues", fmt="g");  

    # Labels, title and ticks
    label_font = {'size':'25'}  # Adjust to fit
    ax.set_xlabel('Predicted labels', fontdict=label_font);
    ax.set_ylabel('Observed labels', fontdict=label_font);

    # title_font = {'size':'21'}  # Adjust to fit
    # ax.set_title('Confusion Matrix', fontdict=title_font);

    ax.tick_params(axis='both', which='major', labelsize=25)  # Adjust to fit
    ax.xaxis.set_ticklabels(['Good', 'Wearing-Off']);
    ax.yaxis.set_ticklabels(['Good', 'Wearing-Off']);
    plt.rc('text') # , usetex=False)
    plt.rc('font', family='serif')
    # plt.savefig('./participant2-downsampling-confusionmatrix-real.pdf', bbox_inches='tight')
    plt.show()

# %%
# Write other reports to summary file
def add_other_report_to_summary(pipeline, with_estimator_comparison=True):
    with open(f'{pipeline.output_settings.results_folder}/photon_summary.txt', "a+") as summary_file:
        # 1. Write comparison of learning algorithms
        if with_estimator_comparison:
            summary_file.write("\n\n")
            summary_file.write("Comparison on learning algorithms on validation set")
            summary_file.write("\n")
            summary_file.write(str(pipeline.results_handler.get_mean_of_best_validation_configs_per_estimator()))

        # 2. Write feature importance
        summary_file.write("\n\n")
        summary_file.write("Feature Importance")
        summary_file.write(print_feature_importances(pipeline))
        
        # 3. Write beautified average test performance across outer folds
        # a. Get Average Test Performance Across Outer Folds
        test_metric_result = pipeline.results.get_test_metric_dict()
        
        # b. Replace display metric name
        #   Reference: https://stackoverflow.com/a/55250496/2303766
        test_metric_result = { metrics[metric]: test_metric_result[metric]
                                  for metric, metric_name in metrics.items() if metric in test_metric_result
                             }
        
        # c. Add beautified average test performance across outer folds to file 
        summary_file.write("\n\n")
        summary_file.write("Average Test Performance Across Outer Folds")
        summary_file.write("\n")
        summary_file.write(
            tabulate(
                pd.DataFrame(
                    test_metric_result
                ).round(4).transpose(),
                tablefmt='psql', floatfmt=".4f", headers='keys'
            )
        )
        
        # 4. Write outer fold results
        summary_file.write("\n\n")
        summary_file.write("Outer Fold Best Estimators' Performance")
        summary_file.write("\n")
        handler = pipeline.results_handler
        performance_table = handler.get_performance_table()
        with pd.option_context('display.max_rows', None, 'display.max_columns', None):
            summary_file.write(
                tabulate(
                    performance_table.loc[:, ['fold', 'best_config', 'n_train', 'n_validation']].transpose(),
                    tablefmt='psql', headers='keys'
                )
            )
            summary_file.write("\n")
            summary_file.write(
                tabulate(
                    performance_table.loc[:, ['fold'] + list(metrics.keys())].round(4).transpose(),
                    tablefmt='psql', floatfmt=".4f", headers='keys'
                )
            )
            
        outer_fold_performance = {}
        config_evals = handler.get_config_evaluations()
        for metric in metrics.keys():
            # print(f'{metric}')
            for i, j in enumerate(config_evals[metric]):
                if f'{metric}_mean' in outer_fold_performance:
                    # outer_fold_performance[f'{metric}_max'].append(np.max(j))
                    outer_fold_performance[f'{metric}_mean'].append(np.mean(j))
                    outer_fold_performance[f'{metric}_std'].append(np.std(j))
                else:
                    # outer_fold_performance[f'{metric}_max'] = [np.max(j)]
                    outer_fold_performance[f'{metric}_mean'] = [np.mean(j)]
                    outer_fold_performance[f'{metric}_std'] = [np.std(j)]
        summary_file.write("\n")
        summary_file.write(
            tabulate(
                pd.DataFrame(outer_fold_performance).round(4).transpose(),
                tablefmt='psql', floatfmt=".4f", headers='keys'
            )
        )

# %%
# PhotonAI Optimize Monkey-patch
#     Added random_state for Optimize for result replicability
def prepare(self, pipeline_elements: list, maximize_metric: bool) -> None:
    """
    Initializes hyperparameter search with scikit-optimize.

    Assembles all hyperparameters of the list of PipelineElements
    in order to prepare the hyperparameter space.
    Hyperparameters can be accessed via pipe_element.hyperparameters.

    Parameters:
        pipeline_elements:
            List of all PipelineElements to create the hyperparameter space.

        maximize_metric:
            Boolean to distinguish between score and error.

    """
    self.start_time = None
    self.optimizer = None
    self.hyperparameter_list = []
    self.maximize_metric = maximize_metric

    # build skopt space
    space = []
    for pipe_element in pipeline_elements:
        if pipe_element.__class__.__name__ == 'Switch':
            error_msg = 'Scikit-Optimize cannot operate in the specified hyperparameter space with a Switch ' \
                        'element. We recommend the use of SMAC.'
            logger.error(error_msg)
            raise ValueError(error_msg)

        if hasattr(pipe_element, 'hyperparameters'):
            for name, value in pipe_element.hyperparameters.items():
                # if we only have one value we do not need to optimize
                if isinstance(value, list) and len(value) < 2:
                    self.constant_dictionary[name] = value[0]
                    continue
                if isinstance(value, PhotonCategorical) and len(value.values) < 2:
                    self.constant_dictionary[name] = value.values[0]
                    continue
                skopt_param = self._convert_photonai_to_skopt_space(value, name)
                if skopt_param is not None:
                    space.append(skopt_param)

    if self.constant_dictionary:
        msg = "PHOTONAI has detected some one-valued params in your hyperparameters. Pleas use the kwargs for " \
              "constant values. This run ignores following settings: " + str(self.constant_dictionary.keys())
        logger.warning(msg)
        warnings.warn(msg)

    if len(space) == 0:
        msg = "Did not find any hyperparameter to convert into skopt space."
        logger.warning(msg)
        warnings.warn(msg)
    else:
        self.optimizer = Optimizer(space,
                                   base_estimator=self.base_estimator,
                                   n_initial_points=self.n_initial_points,
                                   initial_point_generator=self.initial_point_generator,
                                   acq_func=self.acq_func,
                                   acq_func_kwargs=self.acq_func_kwargs,
                                   random_state=4
                                  )
    self.ask = self.ask_generator()
    
#    Monkey patched new prepare function
SkOptOptimizer.prepare = prepare

# %% [markdown]
# ## Visualize Data Split

# %%
# Outer CV
fig, ax = plt.subplots(figsize=(20,10))
cv = StratifiedKFold(n_splits=5, shuffle=False)
plot_cv_indices(cv, X, y, ax)
plt.rc('text') # , usetex=False)
plt.rc('font', family='serif')
plt.title('Outer Folds')
# Save as file
# plt.savefig('./blockingtimeseriessplit.pdf', bbox_inches='tight')
plt.show()

training_folds = []
for train, test in cv.split(X, y):
    print(f'Train Set for Outer Fold {len(training_folds)}')
    print(train)
    training_folds.append(train)
    # print("Test")
    # print(test[0], test[-1])
    print()
# Out:
# Train Set for Outer Fold 0
# [ 30730  30731  30732 ... 172797 172798 172799]
#
# Train Set for Outer Fold 1
# [     0      1      2 ... 172797 172798 172799]
#
# Train Set for Outer Fold 2
# [     0      1      2 ... 172797 172798 172799]
#
# Train Set for Outer Fold 3
# [     0      1      2 ... 172797 172798 172799]
#
# Train Set for Outer Fold 4
# [     0      1      2 ... 138703 138704 138705]

# %%
# Inner CV
outer_fold_number = 0

cmap_data = plt.cm.Paired
cmap_cv = plt.cm.coolwarm
fig, ax = plt.subplots(figsize=(20,10))
cv = StratifiedKFold(n_splits=3, shuffle=False)
plot_cv_indices(cv, X.iloc[training_folds[outer_fold_number]], y[training_folds[outer_fold_number]], ax)
plt.rc('text') # , usetex=False)
plt.rc('font', family='serif')
plt.title(f'Inner Fold for Outer Fold {outer_fold_number}')
# Save as file
# plt.savefig('./blockingtimeseriessplit.pdf', bbox_inches='tight')
plt.show()

inner_training_folds = []
print(f'Train Sets for Outer Fold {outer_fold_number}')
for train, test in cv.split(X.iloc[training_folds[outer_fold_number]], y[training_folds[outer_fold_number]]):
    print(f'Train Set for Inner Fold {len(inner_training_folds)}')
    print(train)
    inner_training_folds.append(train)
    # print("Test")
    # print(test[0], test[-1])
    print()
# Out:
# Train Sets for Outer Fold 0
# Train Set for Inner Fold 0
# [  1502   1503   1504 ... 138237 138238 138239]
#
# Train Set for Inner Fold 1
# [     0      1      2 ... 138237 138238 138239]
#
# Train Set for Inner Fold 2
# [    0     1     2 ... 92757 92758 92759]

# %% [markdown]
# # Pipeline

# %% [markdown]
# ## Define learning algorithms

# %%
estimator_selection = Switch('estimators')
estimator_selection += PipelineElement("LogisticRegression",
                           hyperparameters={
                               'C': FloatRange(1, 10)
                           }, class_weight='balanced', random_state=4)
estimator_selection += PipelineElement("DecisionTreeClassifier",
                           hyperparameters={
                               'min_samples_split': IntegerRange(2,30),
                               'min_samples_leaf': IntegerRange(2,30)
                           }, random_state=4, criterion='gini')
estimator_selection += PipelineElement('LinearSVC',
                            hyperparameters={
                                'C': FloatRange(1, 25)
                            }, class_weight='balanced', random_state=4)
estimator_selection += PipelineElement('RandomForestClassifier', 
                            hyperparameters={
                                'min_samples_split': IntegerRange(2,30),
                                'max_features': ['auto', 'sqrt', 'log2']
                            }, random_state=4, criterion='gini', bootstrap=True)
estimator_selection += PipelineElement('GradientBoostingClassifier', 
                            hyperparameters={
                                'loss': ['deviance', 'exponential'],
                                'learning_rate': FloatRange(0.001, 1, 'logspace')
                            }, random_state=4)

# %% [markdown]
# ## Initial Pipeline

# %%
initial_pipeline = Hyperpipe('1 - Initial Pipeline',
                     outer_cv = StratifiedKFold(n_splits=5, shuffle=False),
                     inner_cv = StratifiedKFold(n_splits=3, shuffle=False),
                     use_test_set = False,
                     metrics = list(metrics.keys()),
                     best_config_metric='balanced_accuracy',
                     optimizer='switch',
                     optimizer_params={'name': 'sk_opt', 'n_configurations': 30},
                     project_folder=f'./analysis/{dataset_type}{user}_{frequency}',
                     cache_folder=f'./cache/{dataset_type}{user}_{frequency}/',
                     verbosity=1,
                     performance_constraints=[MinimumPerformanceConstraint('balanced_accuracy', 0.75, 'mean')])

# Add learning algorithms to compare
initial_pipeline += estimator_selection

# Fit hyperpipe
initial_pipeline.fit(X, y)

# Show learning algorithms mean validation results
# print("Comparison on learning algorithms on validation set")
# print(initial_pipeline.results_handler.get_mean_of_best_validation_configs_per_estimator())

# # Show feature importances
# print_feature_importances(initial_pipeline)

# # View CV splits for debugging
# for k,v in initial_pipeline.cross_validation.outer_folds.items():
#     print(v.train_indices)
#     print(v.test_indices)
#     print(len(v.train_indices), len(v.test_indices))
#     print()

# Write other reports to summary file
add_other_report_to_summary(initial_pipeline)
# Out:
# 11/06/2025-20:40:17 | Output Folder: ./analysis/participant2_15s\1InitialPipeline_results_2025-06-11_20-40-17
# =====================================================================================================
# PHOTONAI ANALYSIS: 1InitialPipeline
# =====================================================================================================
# 11/06/2025-20:40:17 | Preparing data and PHOTONAI objects for analysis...
# 11/06/2025-20:40:17 | Checking input data...
# 11/06/2025-20:40:17 | Running analysis with 172800 samples.
# Found 2 target classes: [0 1]
# Target classes are imbalanced: 97.40104166666667% belongs to 0
# 11/06/2025-20:40:17 | Removing cache files...
#
# *****************************************************************************************************
# Outer Cross validation Fold 1
# *****************************************************************************************************
# 11/06/2025-20:40:17 | Preparing data for outer fold 1...
# 11/06/2025-20:40:17 | Preparing Hyperparameter Optimization...
# 11/06/2025-20:40:17 | Running Dummy Estimator...
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LogisticRegression__C
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LogisticRegression__C=6.473908725279471",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-20:41:00 | Computed configuration 25/150 in 0:00:01.501233
# 11/06/2025-20:41:00 | Performance:             balanced_accuracy - Train: 0.9738, Validation: 0.7824
# 11/06/2025-20:41:00 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LogisticRegression__C=6.474574273862286",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-20:41:02 | Computed configuration 26/150 in 0:00:01.515660
# 11/06/2025-20:41:02 | Performance:             balanced_accuracy - Train: 0.9806, Validation: 0.7566
# 11/06/2025-20:41:02 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LogisticRegression__C=6.47446763358882",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-20:41:03 | Computed configuration 27/150 in 0:00:01.650233
# 11/06/2025-20:41:03 | Performance:             balanced_accuracy - Train: 0.9741, Validation: 0.7665
# 11/06/2025-20:41:03 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LogisticRegression__C=6.460942084111569",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-20:41:05 | Computed configuration 28/150 in 0:00:01.500309
# 11/06/2025-20:41:05 | Performance:             balanced_accuracy - Train: 0.9814, Validation: 0.7520
# 11/06/2025-20:41:05 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LogisticRegression__C=6.432494484623085",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-20:41:07 | Computed configuration 29/150 in 0:00:01.507227
# 11/06/2025-20:41:07 | Performance:             balanced_accuracy - Train: 0.9740, Validation: 0.7711
# 11/06/2025-20:41:07 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LogisticRegression__C=6.469892169592111",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-20:41:09 | Computed configuration 30/150 in 0:00:01.651818
# 11/06/2025-20:41:09 | Performance:             balanced_accuracy - Train: 0.9736, Validation: 0.7699
# 11/06/2025-20:41:09 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=16",
#         "DecisionTreeClassifier__min_samples_leaf=25",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:09 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:09 | Computed configuration 31/150 in 0:00:00.133894
# 11/06/2025-20:41:09 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.7379
# 11/06/2025-20:41:09 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=7",
#         "DecisionTreeClassifier__min_samples_leaf=3",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:09 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:09 | Computed configuration 32/150 in 0:00:00.133474
# 11/06/2025-20:41:09 | Performance:             balanced_accuracy - Train: 0.9996, Validation: 0.7384
# 11/06/2025-20:41:09 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=25",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:09 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:09 | Computed configuration 33/150 in 0:00:00.137933
# 11/06/2025-20:41:09 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.7379
# 11/06/2025-20:41:09 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=20",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:10 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:10 | Computed configuration 34/150 in 0:00:00.135213
# 11/06/2025-20:41:10 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:10 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=11",
#         "DecisionTreeClassifier__min_samples_leaf=28",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:10 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:10 | Computed configuration 35/150 in 0:00:00.151036
# 11/06/2025-20:41:10 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.7379
# 11/06/2025-20:41:10 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=30",
#         "DecisionTreeClassifier__min_samples_leaf=9",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:10 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:10 | Computed configuration 36/150 in 0:00:00.130370
# 11/06/2025-20:41:10 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:10 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=15",
#         "DecisionTreeClassifier__min_samples_leaf=25",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:10 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:10 | Computed configuration 37/150 in 0:00:00.124970
# 11/06/2025-20:41:10 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.7379
# 11/06/2025-20:41:10 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=25",
#         "DecisionTreeClassifier__min_samples_leaf=27",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:10 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:10 | Computed configuration 38/150 in 0:00:00.140627
# 11/06/2025-20:41:10 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.7379
# 11/06/2025-20:41:10 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=6",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:10 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:10 | Computed configuration 39/150 in 0:00:00.171799
# 11/06/2025-20:41:10 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:10 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=20",
#         "DecisionTreeClassifier__min_samples_leaf=14",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:10 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:10 | Computed configuration 40/150 in 0:00:00.140624
# 11/06/2025-20:41:10 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:10 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=2",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:11 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:11 | Computed configuration 41/150 in 0:00:00.140596
# 11/06/2025-20:41:11 | Performance:             balanced_accuracy - Train: 0.9996, Validation: 0.7384
# 11/06/2025-20:41:11 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=25",
#         "DecisionTreeClassifier__min_samples_leaf=7",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:11 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:11 | Computed configuration 42/150 in 0:00:00.140623
# 11/06/2025-20:41:11 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:11 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=14",
#         "DecisionTreeClassifier__min_samples_leaf=11",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:12 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:12 | Computed configuration 43/150 in 0:00:00.138247
# 11/06/2025-20:41:12 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:12 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=15",
#         "DecisionTreeClassifier__min_samples_leaf=28",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:12 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:12 | Computed configuration 44/150 in 0:00:00.151533
# 11/06/2025-20:41:12 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.7379
# 11/06/2025-20:41:12 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=12",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:12 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:12 | Computed configuration 45/150 in 0:00:00.133155
# 11/06/2025-20:41:12 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:12 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=5",
#         "DecisionTreeClassifier__min_samples_leaf=3",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:13 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:13 | Computed configuration 46/150 in 0:00:00.152478
# 11/06/2025-20:41:13 | Performance:             balanced_accuracy - Train: 0.9996, Validation: 0.7384
# 11/06/2025-20:41:13 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=16",
#         "DecisionTreeClassifier__min_samples_leaf=9",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:13 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:13 | Computed configuration 47/150 in 0:00:00.133117
# 11/06/2025-20:41:13 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:13 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=6",
#         "DecisionTreeClassifier__min_samples_leaf=2",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:13 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:13 | Computed configuration 48/150 in 0:00:00.133660
# 11/06/2025-20:41:14 | Performance:             balanced_accuracy - Train: 0.9996, Validation: 0.7384
# 11/06/2025-20:41:14 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=8",
#         "DecisionTreeClassifier__min_samples_leaf=2",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:14 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:14 | Computed configuration 49/150 in 0:00:00.133598
# 11/06/2025-20:41:14 | Performance:             balanced_accuracy - Train: 0.9996, Validation: 0.7384
# 11/06/2025-20:41:14 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=9",
#         "DecisionTreeClassifier__min_samples_leaf=30",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:14 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:14 | Computed configuration 50/150 in 0:00:00.133693
# 11/06/2025-20:41:14 | Performance:             balanced_accuracy - Train: 0.9988, Validation: 0.7379
# 11/06/2025-20:41:14 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=8",
#         "DecisionTreeClassifier__min_samples_leaf=3",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:15 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:15 | Computed configuration 51/150 in 0:00:00.151306
# 11/06/2025-20:41:15 | Performance:             balanced_accuracy - Train: 0.9996, Validation: 0.7384
# 11/06/2025-20:41:15 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=14",
#         "DecisionTreeClassifier__min_samples_leaf=21",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:15 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:15 | Computed configuration 52/150 in 0:00:00.133578
# 11/06/2025-20:41:15 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.7380
# 11/06/2025-20:41:15 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=18",
#         "DecisionTreeClassifier__min_samples_leaf=12",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:16 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:16 | Computed configuration 53/150 in 0:00:00.150287
# 11/06/2025-20:41:16 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:16 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=5",
#         "DecisionTreeClassifier__min_samples_leaf=13",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:16 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:16 | Computed configuration 54/150 in 0:00:00.133627
# 11/06/2025-20:41:16 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:16 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=7",
#         "DecisionTreeClassifier__min_samples_leaf=4",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:16 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:16 | Computed configuration 55/150 in 0:00:00.150259
# 11/06/2025-20:41:16 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:16 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=26",
#         "DecisionTreeClassifier__min_samples_leaf=23",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:17 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:17 | Computed configuration 56/150 in 0:00:00.133660
# 11/06/2025-20:41:17 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.7380
# 11/06/2025-20:41:17 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=12",
#         "DecisionTreeClassifier__min_samples_leaf=2",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:17 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:17 | Computed configuration 57/150 in 0:00:00.150253
# 11/06/2025-20:41:17 | Performance:             balanced_accuracy - Train: 0.9996, Validation: 0.7384
# 11/06/2025-20:41:17 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=5",
#         "DecisionTreeClassifier__min_samples_leaf=14",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:18 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:18 | Computed configuration 58/150 in 0:00:00.150211
# 11/06/2025-20:41:18 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:18 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=4",
#         "DecisionTreeClassifier__min_samples_leaf=6",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:18 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:18 | Computed configuration 59/150 in 0:00:00.150228
# 11/06/2025-20:41:18 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-20:41:18 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=16",
#         "DecisionTreeClassifier__min_samples_leaf=2",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-20:41:19 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-20:41:19 | Computed configuration 60/150 in 0:00:00.134106
# 11/06/2025-20:41:19 | Performance:             balanced_accuracy - Train: 0.9996, Validation: 0.7384
# 11/06/2025-20:41:19 | Best Performance So Far: balanced_accuracy - Train: 0.9738, Validation: 0.7824
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=22.61491493235211",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:19 | Computed configuration 61/150 in 0:00:00.500280
# 11/06/2025-20:41:19 | Performance:             balanced_accuracy - Train: 0.9719, Validation: 0.8640
# 11/06/2025-20:41:19 | Best Performance So Far: balanced_accuracy - Train: 0.9719, Validation: 0.8640
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=5.144687945726697",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:20 | Computed configuration 62/150 in 0:00:00.500002
# 11/06/2025-20:41:20 | Performance:             balanced_accuracy - Train: 0.9725, Validation: 0.8539
# 11/06/2025-20:41:20 | Best Performance So Far: balanced_accuracy - Train: 0.9719, Validation: 0.8640
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=21.534902760055544",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:20 | Computed configuration 63/150 in 0:00:00.483243
# 11/06/2025-20:41:20 | Performance:             balanced_accuracy - Train: 0.9693, Validation: 0.8720
# 11/06/2025-20:41:20 | Best Performance So Far: balanced_accuracy - Train: 0.9693, Validation: 0.8720
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=15.616854434799341",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:21 | Computed configuration 64/150 in 0:00:00.483435
# 11/06/2025-20:41:21 | Performance:             balanced_accuracy - Train: 0.9662, Validation: 0.8777
# 11/06/2025-20:41:21 | Best Performance So Far: balanced_accuracy - Train: 0.9662, Validation: 0.8777
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=15.341348925129681",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:21 | Computed configuration 65/150 in 0:00:00.483397
# 11/06/2025-20:41:21 | Performance:             balanced_accuracy - Train: 0.9716, Validation: 0.8683
# 11/06/2025-20:41:21 | Best Performance So Far: balanced_accuracy - Train: 0.9662, Validation: 0.8777
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=4.395140166808567",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:22 | Computed configuration 66/150 in 0:00:00.500079
# 11/06/2025-20:41:22 | Performance:             balanced_accuracy - Train: 0.9725, Validation: 0.8535
# 11/06/2025-20:41:22 | Best Performance So Far: balanced_accuracy - Train: 0.9662, Validation: 0.8777
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=6.3881421696359375",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:22 | Computed configuration 67/150 in 0:00:00.499869
# 11/06/2025-20:41:22 | Performance:             balanced_accuracy - Train: 0.9725, Validation: 0.8537
# 11/06/2025-20:41:22 | Best Performance So Far: balanced_accuracy - Train: 0.9662, Validation: 0.8777
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=17.762085661825363",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:23 | Computed configuration 68/150 in 0:00:00.483478
# 11/06/2025-20:41:23 | Performance:             balanced_accuracy - Train: 0.9667, Validation: 0.8758
# 11/06/2025-20:41:23 | Best Performance So Far: balanced_accuracy - Train: 0.9662, Validation: 0.8777
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=22.676284569762625",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:23 | Computed configuration 69/150 in 0:00:00.483276
# 11/06/2025-20:41:23 | Performance:             balanced_accuracy - Train: 0.9663, Validation: 0.8772
# 11/06/2025-20:41:23 | Best Performance So Far: balanced_accuracy - Train: 0.9662, Validation: 0.8777
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=16.191114505419062",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:24 | Computed configuration 70/150 in 0:00:00.500269
# 11/06/2025-20:41:24 | Performance:             balanced_accuracy - Train: 0.9722, Validation: 0.8583
# 11/06/2025-20:41:24 | Best Performance So Far: balanced_accuracy - Train: 0.9662, Validation: 0.8777
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=17.755974633336233",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:25 | Computed configuration 71/150 in 0:00:00.600122
# 11/06/2025-20:41:25 | Performance:             balanced_accuracy - Train: 0.9723, Validation: 0.8559
# 11/06/2025-20:41:25 | Best Performance So Far: balanced_accuracy - Train: 0.9662, Validation: 0.8777
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=19.146086829040552",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:25 | Computed configuration 72/150 in 0:00:00.483692
# 11/06/2025-20:41:25 | Performance:             balanced_accuracy - Train: 0.9662, Validation: 0.8779
# 11/06/2025-20:41:25 | Best Performance So Far: balanced_accuracy - Train: 0.9662, Validation: 0.8779
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "LinearSVC__C=19.130347118668524",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-20:41:26 | Computed configuration 73/150 in 0:00:00.483468
# 11/06/2025-20:41:26 | Performance:             balanced_accuracy - Train: 0.9670, Validation: 0.8754
# 11/06/2025-20:41:26 | Best Performance So Far: balanced_accuracy - Train: 0.9662, Validation: 0.
| Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:08:56 | Computed configuration 141/150 in 0:00:12.922384
# 11/06/2025-21:08:56 | Performance:             balanced_accuracy - Train: 0.6830, Validation: 0.7114
# 11/06/2025-21:08:56 | Best Performance So Far: balanced_accuracy - Train: 0.8133, Validation: 0.7386
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.01782095746097505",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-21:09:03 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:09:03 | Computed configuration 142/150 in 0:00:06.567167
# 11/06/2025-21:09:03 | Performance:             balanced_accuracy - Train: 0.5000, Validation: 0.5000
# 11/06/2025-21:09:03 | Best Performance So Far: balanced_accuracy - Train: 0.8133, Validation: 0.7386
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.031724536260183",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-21:09:17 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:09:17 | Computed configuration 143/150 in 0:00:13.149980
# 11/06/2025-21:09:17 | Performance:             balanced_accuracy - Train: 0.8133, Validation: 0.7135
# 11/06/2025-21:09:17 | Best Performance So Far: balanced_accuracy - Train: 0.8133, Validation: 0.7386
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.022344802084739834",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-21:09:30 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:09:30 | Computed configuration 144/150 in 0:00:13.000887
# 11/06/2025-21:09:30 | Performance:             balanced_accuracy - Train: 0.6934, Validation: 0.7114
# 11/06/2025-21:09:30 | Best Performance So Far: balanced_accuracy - Train: 0.8133, Validation: 0.7386
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.0319492573883071",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-21:09:43 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:09:43 | Computed configuration 145/150 in 0:00:13.034230
# 11/06/2025-21:09:43 | Performance:             balanced_accuracy - Train: 0.8175, Validation: 0.7116
# 11/06/2025-21:09:43 | Best Performance So Far: balanced_accuracy - Train: 0.8133, Validation: 0.7386
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.03203411632367221",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-21:09:57 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:09:57 | Computed configuration 146/150 in 0:00:13.300974
# 11/06/2025-21:09:57 | Performance:             balanced_accuracy - Train: 0.8175, Validation: 0.7078
# 11/06/2025-21:09:57 | Best Performance So Far: balanced_accuracy - Train: 0.8133, Validation: 0.7386
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.032093504818317194",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-21:10:10 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:10:10 | Computed configuration 147/150 in 0:00:13.150839
# 11/06/2025-21:10:10 | Performance:             balanced_accuracy - Train: 0.8175, Validation: 0.7078
# 11/06/2025-21:10:10 | Best Performance So Far: balanced_accuracy - Train: 0.8133, Validation: 0.7386
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.03201282734433329",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-21:10:24 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:10:24 | Computed configuration 148/150 in 0:00:13.317626
# 11/06/2025-21:10:24 | Performance:             balanced_accuracy - Train: 0.8175, Validation: 0.7165
# 11/06/2025-21:10:24 | Best Performance So Far: balanced_accuracy - Train: 0.8133, Validation: 0.7386
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.021812335384274746",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-21:10:37 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:10:37 | Computed configuration 149/150 in 0:00:12.901072
# 11/06/2025-21:10:37 | Performance:             balanced_accuracy - Train: 0.6934, Validation: 0.7114
# 11/06/2025-21:10:37 | Best Performance So Far: balanced_accuracy - Train: 0.8133, Validation: 0.7386
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.017195601679728407",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-21:10:44 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:10:44 | Computed configuration 150/150 in 0:00:06.516740
# 11/06/2025-21:10:44 | Performance:             balanced_accuracy - Train: 0.5000, Validation: 0.5000
# 11/06/2025-21:10:44 | Best Performance So Far: balanced_accuracy - Train: 0.8133, Validation: 0.7386
# -----------------------------------------------------------------------------------------------------
# 11/06/2025-21:10:44 | Hyperparameter Optimization finished. Now finding best configuration ....
# 11/06/2025-21:10:44 | 150
# -----------------------------------------------------------------------------------------------------
# BEST_CONFIG
# -----------------------------------------------------------------------------------------------------
# {
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.031882369010951664",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# -----------------------------------------------------------------------------------------------------
# VALIDATION PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +-------------------+-------------------+------------------+
# |       METRIC      | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +-------------------+-------------------+------------------+
# | balanced_accuracy |       0.8133      |      0.7386      |
# |      f1_score     |       0.6997      |      0.3012      |
# |      accuracy     |       0.9898      |      0.8188      |
# |     precision     |       0.9317      |      0.5351      |
# |    sensitivity    |       0.6271      |      0.6541      |
# |    specificity    |       0.9994      |      0.8232      |
# |        auc        |       0.8133      |      0.7386      |
# +-------------------+-------------------+------------------+
# 11/06/2025-21:10:54 | Computations in outer fold 5 took 6.427615433333333 minutes.
# 11/06/2025-21:10:54 | Writing results to project folder...
#
# *****************************************************************************************************
# Finished all outer fold computations.
# 11/06/2025-21:11:16 | Now analysing the final results...
# 11/06/2025-21:11:16 | Computing dummy metrics...
# 11/06/2025-21:11:16 | Computing mean and std for all outer fold metrics...
# 11/06/2025-21:11:16 | Find best config across outer folds...
# 11/06/2025-21:11:16 | Save final results...
# 11/06/2025-21:11:16 | Writing results to project folder...
# 11/06/2025-21:11:40 | Prepare Hyperpipe.optimum pipe with best config..
# 11/06/2025-21:11:40 | Fitting best model...
# 11/06/2025-21:11:40 | Saved best model to file.
# 11/06/2025-21:11:40 | Summarizing results...
# 11/06/2025-21:11:40 | Write predictions to files...
# 11/06/2025-21:11:41 | Write summary...
# *****************************************************************************************************
#
# ANALYSIS INFORMATION ================================================================================
# Project Folder: ./analysis/participant2_15s\1InitialPipeline_results_2025-06-11_20-40-17,
# Computation Time: 2025-06-11 20:40:17.173039 - 2025-06-11 21:11:16.615801
# Duration: 0:30:59.442762
# Optimized for: balanced_accuracy
# Hyperparameter Optimizer: switch
#
# DUMMY RESULTS =======================================================================================
# +-------------------+--+
# | PERFORMANCE DUMMY |  |
# +-------------------+--+
# +-------------------+--+
#
# AVERAGE PERFORMANCE ACROSS OUTER FOLDS ==============================================================
# +-------------------+---------------+--------------+-----------+----------+
# |    Metric Name    | Training Mean | Training Std | Test Mean | Test Std |
# +-------------------+---------------+--------------+-----------+----------+
# | balanced_accuracy |    0.924595   |   0.076252   |  0.75193  | 0.065599 |
# |      f1_score     |    0.822882   |   0.156739   |  0.232884 | 0.187994 |
# |      accuracy     |    0.989277   |   0.012753   |  0.698739 | 0.162306 |
# |     precision     |    0.87166    |   0.215849   |  0.245934 | 0.238515 |
# |    sensitivity    |    0.856367   |   0.156665   |  0.808036 | 0.081761 |
# |    specificity    |    0.992823   |   0.013909   |  0.695825 | 0.168031 |
# |        auc        |    0.924595   |   0.076252   |  0.75193  | 0.065599 |
# +-------------------+---------------+--------------+-----------+----------+
#
# BEST HYPERPARAMETER CONFIGURATION ===================================================================
# {
#     "estimators": [
#         "LinearSVC__C=19.134829457071934",
#         "estimator_name=LinearSVC"
#     ]
# }
#
#
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | fold # | balanced_accuracy | f1_score | accuracy | precision | sensitivity | specificity |  auc   |                                                                            Best Hyperparameter Config                                                                           |
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   1*   |       0.8785      |  0.5735  |  0.9477  |   0.5409  |    0.8054   |    0.9515   | 0.8785 |                                                 {'estimators': ['LinearSVC__C=19.134829457071934', 'estimator_name=LinearSVC']}                                                 |
# |   2    |       0.7091      |  0.0920  |  0.5513  |   0.0486  |    0.8755   |    0.5427   | 0.7091 |              {'estimators': ['RandomForestClassifier__min_samples_split=11', 'RandomForestClassifier__max_features=sqrt', 'estimator_name=RandomForestClassifier']}             |
# |   3    |       0.7393      |  0.1109  |  0.6552  |   0.0594  |    0.8279   |    0.6506   | 0.7393 | {'estimators': ['GradientBoostingClassifier__loss=exponential', 'GradientBoostingClassifier__learning_rate=0.021478792836934265', 'estimator_name=GradientBoostingClassifier']} |
# |   4    |       0.6942      |  0.0868  |  0.5207  |   0.0457  |    0.8772   |    0.5112   | 0.6942 |  {'estimators': ['GradientBoostingClassifier__loss=exponential', 'GradientBoostingClassifier__learning_rate=0.02797399414481752', 'estimator_name=GradientBoostingClassifier']} |
# |   5    |       0.7386      |  0.3012  |  0.8188  |   0.5351  |    0.6541   |    0.8232   | 0.7386 | {'estimators': ['GradientBoostingClassifier__loss=exponential', 'GradientBoostingClassifier__learning_rate=0.031882369010951664', 'estimator_name=GradientBoostingClassifier']} |
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# PHOTONAI 2.5.0 ======================================================================================
# Your results are stored in ./analysis/participant2_15s\1InitialPipeline_results_2025-06-11_20-40-17
# Go to https://explorer.photon-ai.com and upload your photonai_results.json for convenient result visualization!
# For more info and documentation visit https://www.photon-ai.com

# %% [markdown]
# ## Feature Selection Pipeline

# %%
classifier = LogisticRegression(random_state=4).fit(X, y)

feature_selection_pipeline = Hyperpipe('2 - Feature Selection Pipline',
                     outer_cv = StratifiedKFold(n_splits=5, shuffle=False),
                     inner_cv = StratifiedKFold(n_splits=3, shuffle=False),
                     use_test_set = False,
                     metrics = list(metrics.keys()),
                     best_config_metric='balanced_accuracy',
                     optimizer='switch',
                     optimizer_params={'name': 'sk_opt', 'n_configurations': 30},
                     project_folder=f'./analysis/{dataset_type}{user}_{frequency}',
                     cache_folder=f'./cache/{dataset_type}{user}_{frequency}/',
                     verbosity=1,
                     performance_constraints=[MinimumPerformanceConstraint('balanced_accuracy', 0.75, 'mean')])

feature_selection_pipeline += PipelineElement('RFE', 
                           hyperparameters={
                               'n_features_to_select': IntegerRange(2, (len(columns) - 2))
                           }, estimator=classifier)

feature_selection_pipeline += estimator_selection

# Fit hyperpipe
feature_selection_pipeline.fit(X, y)

# Show learning algorithms mean validation results
# print("Comparison on learning algorithms on validation set")
# print(feature_selection_pipeline.results_handler.get_mean_of_best_validation_configs_per_estimator())

# # Show feature importances
# print_feature_importances(feature_selection_pipeline)

# # View CV splits for debugging
# for k,v in feature_selection_pipeline.cross_validation.outer_folds.items():
#     print(v.train_indices)
#     print(v.test_indices)
#     print(len(v.train_indices), len(v.test_indices))
#     print()

# Write other reports to summary file
add_other_report_to_summary(feature_selection_pipeline)
# Out:
# 11/06/2025-21:11:42 | Output Folder: ./analysis/participant2_15s\2FeatureSelectionPipline_results_2025-06-11_21-11-42
# =====================================================================================================
# PHOTONAI ANALYSIS: 2FeatureSelectionPipline
# =====================================================================================================
# 11/06/2025-21:11:42 | Preparing data and PHOTONAI objects for analysis...
# 11/06/2025-21:11:42 | Checking input data...
# 11/06/2025-21:11:42 | Running analysis with 172800 samples.
# Found 2 target classes: [0 1]
# Target classes are imbalanced: 97.40104166666667% belongs to 0
# JsonTransformer was unable to create the .json file.
# 11/06/2025-21:11:42 | Removing cache files...
#
# *****************************************************************************************************
# Outer Cross validation Fold 1
# *****************************************************************************************************
# 11/06/2025-21:11:42 | Preparing data for outer fold 1...
# 11/06/2025-21:11:42 | Preparing Hyperparameter Optimization...
# 11/06/2025-21:11:42 | Running Dummy Estimator...
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=9"
#     ],
#     "estimators": [
#         "LogisticRegression__C=2.5542579796475113",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:11:44 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:11
| Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=9.890225615522743",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:12:30 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:30 | Computed configuration 27/150 in 0:00:01.683592
# 11/06/2025-21:12:30 | Performance:             balanced_accuracy - Train: 0.9801, Validation: 0.7489
# 11/06/2025-21:12:30 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=9.918366570383963",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:12:31 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:31 | Computed configuration 28/150 in 0:00:01.683784
# 11/06/2025-21:12:31 | Performance:             balanced_accuracy - Train: 0.9810, Validation: 0.7485
# 11/06/2025-21:12:31 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=9.72046152804297",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:12:34 | Computed configuration 29/150 in 0:00:01.872845
# 11/06/2025-21:12:34 | Performance:             balanced_accuracy - Train: 0.9731, Validation: 0.7691
# 11/06/2025-21:12:34 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=9.953894496251538",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:12:36 | Computed configuration 30/150 in 0:00:01.667075
# 11/06/2025-21:12:36 | Performance:             balanced_accuracy - Train: 0.9740, Validation: 0.7705
# 11/06/2025-21:12:36 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=9"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=7",
#         "DecisionTreeClassifier__min_samples_leaf=3",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:36 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:36 | Computed configuration 31/150 in 0:00:00.137506
# 11/06/2025-21:12:36 | Performance:             balanced_accuracy - Train: 0.8726, Validation: 0.3828
# 11/06/2025-21:12:36 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=10"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=25",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:36 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:36 | Computed configuration 32/150 in 0:00:00.149788
# 11/06/2025-21:12:36 | Performance:             balanced_accuracy - Train: 0.9681, Validation: 0.4376
# 11/06/2025-21:12:36 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=4"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=11",
#         "DecisionTreeClassifier__min_samples_leaf=28",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:36 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:36 | Computed configuration 33/150 in 0:00:00.116642
# 11/06/2025-21:12:36 | Performance:             balanced_accuracy - Train: 0.8025, Validation: 0.2595
# 11/06/2025-21:12:36 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=9"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=15",
#         "DecisionTreeClassifier__min_samples_leaf=25",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:36 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:36 | Computed configuration 34/150 in 0:00:00.157815
# 11/06/2025-21:12:36 | Performance:             balanced_accuracy - Train: 0.8427, Validation: 0.3218
# 11/06/2025-21:12:36 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=9"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=27",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:37 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:37 | Computed configuration 35/150 in 0:00:00.333549
# 11/06/2025-21:12:37 | Performance:             balanced_accuracy - Train: 0.8540, Validation: 0.2556
# 11/06/2025-21:12:37 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=6"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=20",
#         "DecisionTreeClassifier__min_samples_leaf=14",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:37 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:37 | Computed configuration 36/150 in 0:00:00.133272
# 11/06/2025-21:12:37 | Performance:             balanced_accuracy - Train: 0.8025, Validation: 0.3236
# 11/06/2025-21:12:37 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=8"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=12",
#         "DecisionTreeClassifier__min_samples_leaf=22",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:37 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:37 | Computed configuration 37/150 in 0:00:00.133570
# 11/06/2025-21:12:37 | Performance:             balanced_accuracy - Train: 0.8216, Validation: 0.3208
# 11/06/2025-21:12:37 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=5"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=2",
#         "DecisionTreeClassifier__min_samples_leaf=25",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:40 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:40 | Computed configuration 38/150 in 0:00:03.016823
# 11/06/2025-21:12:40 | Performance:             balanced_accuracy - Train: 0.8025, Validation: 0.3878
# 11/06/2025-21:12:40 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=7"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=23",
#         "DecisionTreeClassifier__min_samples_leaf=11",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:42 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:42 | Computed configuration 39/150 in 0:00:02.383564
# 11/06/2025-21:12:42 | Performance:             balanced_accuracy - Train: 0.8249, Validation: 0.3208
# 11/06/2025-21:12:42 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=8"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=8",
#         "DecisionTreeClassifier__min_samples_leaf=26",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:43 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:43 | Computed configuration 40/150 in 0:00:00.133455
# 11/06/2025-21:12:43 | Performance:             balanced_accuracy - Train: 0.8216, Validation: 0.3208
# 11/06/2025-21:12:43 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=11"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=26",
#         "DecisionTreeClassifier__min_samples_leaf=2",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:43 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:43 | Computed configuration 41/150 in 0:00:00.166950
# 11/06/2025-21:12:43 | Performance:             balanced_accuracy - Train: 0.9712, Validation: 0.4369
# 11/06/2025-21:12:43 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=11"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=29",
#         "DecisionTreeClassifier__min_samples_leaf=9",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:43 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:43 | Computed configuration 42/150 in 0:00:00.150294
# 11/06/2025-21:12:43 | Performance:             balanced_accuracy - Train: 0.9691, Validation: 0.4379
# 11/06/2025-21:12:43 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=10"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=28",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:44 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:44 | Computed configuration 43/150 in 0:00:00.169947
# 11/06/2025-21:12:44 | Performance:             balanced_accuracy - Train: 0.9681, Validation: 0.4376
# 11/06/2025-21:12:44 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=28",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:44 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:44 | Computed configuration 44/150 in 0:00:00.164840
# 11/06/2025-21:12:44 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-21:12:44 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=6"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=26",
#         "DecisionTreeClassifier__min_samples_leaf=26",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:45 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:45 | Computed configuration 45/150 in 0:00:00.116917
# 11/06/2025-21:12:45 | Performance:             balanced_accuracy - Train: 0.8025, Validation: 0.3236
# 11/06/2025-21:12:45 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=29",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:45 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:45 | Computed configuration 46/150 in 0:00:00.174721
# 11/06/2025-21:12:45 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.7380
# 11/06/2025-21:12:45 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=11"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=29",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:45 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:45 | Computed configuration 47/150 in 0:00:00.166931
# 11/06/2025-21:12:45 | Performance:             balanced_accuracy - Train: 0.9681, Validation: 0.4380
# 11/06/2025-21:12:45 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=3"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=21",
#         "DecisionTreeClassifier__min_samples_leaf=2",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:49 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:49 | Computed configuration 48/150 in 0:00:03.340710
# 11/06/2025-21:12:49 | Performance:             balanced_accuracy - Train: 0.8025, Validation: 0.2595
# 11/06/2025-21:12:49 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=3"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=11",
#         "DecisionTreeClassifier__min_samples_leaf=28",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:49 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:49 | Computed configuration 49/150 in 0:00:00.100357
# 11/06/2025-21:12:49 | Performance:             balanced_accuracy - Train: 0.8025, Validation: 0.2595
# 11/06/2025-21:12:49 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=11"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=30",
#         "DecisionTreeClassifier__min_samples_leaf=8",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:50 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:50 | Computed configuration 50/150 in 0:00:00.166694
# 11/06/2025-21:12:50 | Performance:             balanced_accuracy - Train: 0.9694, Validation: 0.4383
# 11/06/2025-21:12:50 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=4"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=30",
#         "DecisionTreeClassifier__min_samples_leaf=23",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:50 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:50 | Computed configuration 51/150 in 0:00:00.102011
# 11/06/2025-21:12:50 | Performance:             balanced_accuracy - Train: 0.8025, Validation: 0.2595
# 11/06/2025-21:12:50 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=11"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=28",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:51 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:51 | Computed configuration 52/150 in 0:00:00.150633
# 11/06/2025-21:12:51 | Performance:             balanced_accuracy - Train: 0.9681, Validation: 0.4384
# 11/06/2025-21:12:51 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=11"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=28",
#         "DecisionTreeClassifier__min_samples_leaf=11",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:51 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:51 | Computed configuration 53/150 in 0:00:00.166920
# 11/06/2025-21:12:51 | Performance:             balanced_accuracy - Train: 0.9681, Validation: 0.4384
# 11/06/2025-21:12:51 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=11"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=30",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:52 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:52 | Computed configuration 54/150 in 0:00:00.145523
# 11/06/2025-21:12:52 | Performance:             balanced_accuracy - Train: 0.9681, Validation: 0.4380
# 11/06/2025-21:12:52 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=8"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=12",
#         "DecisionTreeClassifier__min_samples_leaf=17",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:52 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:52 | Computed configuration 55/150 in 0:00:00.133632
# 11/06/2025-21:12:52 | Performance:             balanced_accuracy - Train: 0.8249, Validation: 0.2566
# 11/06/2025-21:12:52 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=7"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=22",
#         "DecisionTreeClassifier__min_samples_leaf=23",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:52 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:52 | Computed configuration 56/150 in 0:00:00.133700
# 11/06/2025-21:12:52 | Performance:             balanced_accuracy - Train: 0.8216, Validation: 0.3208
# 11/06/2025-21:12:52 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=7"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=7",
#         "DecisionTreeClassifier__min_samples_leaf=6",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:53 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:53 | Computed configuration 57/150 in 0:00:00.141389
# 11/06/2025-21:12:53 | Performance:             balanced_accuracy - Train: 0.8249, Validation: 0.2566
# 11/06/2025-21:12:53 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=10"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=21",
#         "DecisionTreeClassifier__min_samples_leaf=5",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:53 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:53 | Computed configuration 58/150 in 0:00:00.144750
# 11/06/2025-21:12:53 | Performance:             balanced_accuracy - Train: 0.9686, Validation: 0.4392
# 11/06/2025-21:12:53 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=9"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=30",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:54 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:54 | Computed configuration 59/150 in 0:00:00.154989
# 11/06/2025-21:12:54 | Performance:             balanced_accuracy - Train: 0.8432, Validation: 0.3847
# 11/06/2025-21:12:54 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=10"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=24",
#         "DecisionTreeClassifier__min_samples_leaf=14",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:12:54 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:54 | Computed configuration 60/150 in 0:00:00.167049
# 11/06/2025-21:12:54 | Performance:             balanced_accuracy - Train: 0.9615, Validation: 0.4391
# 11/06/2025-21:12:54 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=9"
#     ],
#     "estimators": [
#         "LinearSVC__C=5.144687945726697",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:12:55 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:55 | Computed configuration 61/150 in 0:00:00.666905
# 11/06/2025-21:12:55 | Performance:             balanced_accuracy - Train: 0.7911, Validation: 0.1400
# 11/06/2025-21:12:55 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=10"
#     ],
#     "estimators": [
#         "LinearSVC__C=18.155583848184754",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:12:56 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:56 | Computed configuration 62/150 in 0:00:00.816234
# 11/06/2025-21:12:56 | Performance:             balanced_accuracy - Train: 0.7855, Validation: 0.1700
# 11/06/2025-21:12:56 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=4"
#     ],
#     "estimators": [
#         "LinearSVC__C=15.341348925129681",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:12:56 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:56 | Computed configuration 63/150 in 0:00:00.166662
# 11/06/2025-21:12:56 | Performance:             balanced_accuracy - Train: 0.8208, Validation: 0.1067
# 11/06/2025-21:12:56 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=9"
#     ],
#     "estimators": [
#         "LinearSVC__C=6.3881421696359375",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:12:57 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:57 | Computed configuration 64/150 in 0:00:00.516805
# 11/06/2025-21:12:57 | Performance:             balanced_accuracy - Train: 0.7911, Validation: 0.1401
# 11/06/2025-21:12:57 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=9"
#     ],
#     "estimators": [
#         "LinearSVC__C=7.071576697202656",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:12:57 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:57 | Computed configuration 65/150 in 0:00:00.599943
# 11/06/2025-21:12:57 | Performance:             balanced_accuracy - Train: 0.7911, Validation: 0.1401
# 11/06/2025-21:12:57 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=10"
#     ],
#     "estimators": [
#         "LinearSVC__C=16.191114505419062",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:12:58 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:58 | Computed configuration 66/150 in 0:00:00.599947
# 11/06/2025-21:12:58 | Performance:             balanced_accuracy - Train: 0.7858, Validation: 0.1689
# 11/06/2025-21:12:58 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=8"
#     ],
#     "estimators": [
#         "LinearSVC__C=14.736555790244324",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:12:58 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:12:58 | Computed configuration 67/150 in 0:00:00.564911
# 11/06/2025-21:12:58 | Performance:             balanced_accuracy - Train: 0.7959, Validation: 0.1390
# 11/06/2025-21:12:58 | Best Performance So Far: balanced_accuracy - Train: 0.9739, Validation: 0.7850
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select
| Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:33:56 | Computed configuration 150/150 in 0:00:12.450931
# 11/06/2025-21:33:56 | Performance:             balanced_accuracy - Train: 0.6934, Validation: 0.7114
# 11/06/2025-21:33:56 | Best Performance So Far: balanced_accuracy - Train: 0.8627, Validation: 0.7266
# -----------------------------------------------------------------------------------------------------
# 11/06/2025-21:33:56 | Hyperparameter Optimization finished. Now finding best configuration ....
# 11/06/2025-21:33:56 | 150
# -----------------------------------------------------------------------------------------------------
# BEST_CONFIG
# -----------------------------------------------------------------------------------------------------
# {
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.03790903943686681",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# -----------------------------------------------------------------------------------------------------
# VALIDATION PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +-------------------+-------------------+------------------+
# |       METRIC      | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +-------------------+-------------------+------------------+
# | balanced_accuracy |       0.8627      |      0.7266      |
# |      f1_score     |       0.7950      |      0.3275      |
# |      accuracy     |       0.9917      |      0.7597      |
# |     precision     |       0.9157      |      0.5265      |
# |    sensitivity    |       0.7267      |      0.6917      |
# |    specificity    |       0.9987      |      0.7615      |
# |        auc        |       0.8627      |      0.7266      |
# +-------------------+-------------------+------------------+
# 11/06/2025-21:34:06 | Computations in outer fold 5 took 5.331547633333333 minutes.
# 11/06/2025-21:34:06 | Writing results to project folder...
#
# *****************************************************************************************************
# Finished all outer fold computations.
# 11/06/2025-21:34:27 | Now analysing the final results...
# 11/06/2025-21:34:27 | Computing dummy metrics...
# 11/06/2025-21:34:27 | Computing mean and std for all outer fold metrics...
# 11/06/2025-21:34:27 | Find best config across outer folds...
# 11/06/2025-21:34:27 | Save final results...
# 11/06/2025-21:34:27 | Writing results to project folder...
# 11/06/2025-21:34:49 | Prepare Hyperpipe.optimum pipe with best config..
# 11/06/2025-21:34:49 | Fitting best model...
# 11/06/2025-21:34:50 | Saved best model to file.
# 11/06/2025-21:34:50 | Summarizing results...
# 11/06/2025-21:34:50 | Write predictions to files...
# 11/06/2025-21:34:51 | Write summary...
# *****************************************************************************************************
#
# ANALYSIS INFORMATION ================================================================================
# Project Folder: ./analysis/participant2_15s\2FeatureSelectionPipline_results_2025-06-11_21-11-42,
# Computation Time: 2025-06-11 21:11:42.434105 - 2025-06-11 21:34:27.914703
# Duration: 0:22:45.480598
# Optimized for: balanced_accuracy
# Hyperparameter Optimizer: switch
#
# DUMMY RESULTS =======================================================================================
# +-------------------+--+
# | PERFORMANCE DUMMY |  |
# +-------------------+--+
# +-------------------+--+
#
# AVERAGE PERFORMANCE ACROSS OUTER FOLDS ==============================================================
# +-------------------+---------------+--------------+-----------+----------+
# |    Metric Name    | Training Mean | Training Std | Test Mean | Test Std |
# +-------------------+---------------+--------------+-----------+----------+
# | balanced_accuracy |    0.890085   |   0.079662   |  0.746405 | 0.071753 |
# |      f1_score     |    0.666414   |   0.29074    |  0.240684 | 0.188105 |
# |      accuracy     |    0.935192   |   0.10425    |  0.70709  | 0.154642 |
# |     precision     |    0.686735   |   0.367472   |  0.245944 | 0.234961 |
# |    sensitivity    |    0.842505   |   0.132976   |  0.787875 | 0.115699 |
# |    specificity    |    0.937665   |   0.107452   |  0.704936 | 0.160282 |
# |        auc        |    0.890085   |   0.079662   |  0.746405 | 0.071753 |
# +-------------------+---------------+--------------+-----------+----------+
#
# BEST HYPERPARAMETER CONFIGURATION ===================================================================
# {
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LinearSVC__C=24.608200599340357",
#         "estimator_name=LinearSVC"
#     ]
# }
#
#
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | fold # | balanced_accuracy | f1_score | accuracy | precision | sensitivity | specificity |  auc   |                                                                                             Best Hyperparameter Config                                                                                             |
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   1*   |       0.8780      |  0.5726  |  0.9474  |   0.5405  |    0.8049   |    0.9512   | 0.8780 |                                                {'RFE': ['n_features_to_select=12'], 'estimators': ['LinearSVC__C=24.608200599340357', 'estimator_name=LinearSVC']}                                                 |
# |   2    |       0.6626      |  0.0839  |  0.5669  |   0.0444  |    0.7636   |    0.5617   | 0.6626 |             {'RFE': ['n_features_to_select=12'], 'estimators': ['RandomForestClassifier__min_samples_split=13', 'RandomForestClassifier__max_features=log2', 'estimator_name=RandomForestClassifier']}             |
# |   3    |       0.7500      |  0.0964  |  0.5129  |   0.0506  |    1.0000   |    0.4999   | 0.7500 |                                                {'RFE': ['n_features_to_select=10'], 'estimators': ['LinearSVC__C=1.8449172392974011', 'estimator_name=LinearSVC']}                                                 |
# |   4    |       0.7148      |  0.1231  |  0.7486  |   0.0677  |    0.6792   |    0.7505   | 0.7148 |            {'RFE': ['n_features_to_select=8'], 'estimators': ['DecisionTreeClassifier__min_samples_split=12', 'DecisionTreeClassifier__min_samples_leaf=22', 'estimator_name=DecisionTreeClassifier']}             |
# |   5    |       0.7266      |  0.3275  |  0.7597  |   0.5265  |    0.6917   |    0.7615   | 0.7266 | {'RFE': ['n_features_to_select=12'], 'estimators': ['GradientBoostingClassifier__loss=exponential', 'GradientBoostingClassifier__learning_rate=0.03790903943686681', 'estimator_name=GradientBoostingClassifier']} |
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# PHOTONAI 2.5.0 ======================================================================================
# Your results are stored in ./analysis/participant2_15s\2FeatureSelectionPipline_results_2025-06-11_21-11-42
# Go to https://explorer.photon-ai.com and upload your photonai_results.json for convenient result visualization!
# For more info and documentation visit https://www.photon-ai.com

# %% [markdown]
# ## Class Imbalanced Pipeline

# %%
class_imbalanced_pipeline = Hyperpipe('3 - Class Imbalanced Pipline',
                     outer_cv = StratifiedKFold(n_splits=5, shuffle=False),
                     inner_cv = StratifiedKFold(n_splits=3, shuffle=False),
                     use_test_set = False,
                     metrics = list(metrics.keys()),
                     best_config_metric='balanced_accuracy',
                     optimizer='switch',
                     optimizer_params={'name': 'sk_opt', 'n_configurations': 30},
                     project_folder=f'./analysis/{dataset_type}{user}_{frequency}',
                     cache_folder=f'./cache/{dataset_type}{user}_{frequency}/',
                     verbosity=1,
                     performance_constraints=[MinimumPerformanceConstraint('balanced_accuracy', 0.75, 'mean')])

tested_methods = Categorical(['RandomUnderSampler', 'RandomOverSampler', 'SMOTE', 'BorderlineSMOTE'])
class_imbalanced_pipeline += PipelineElement('ImbalancedDataTransformer',
                           hyperparameters={ 'method_name': tested_methods })

class_imbalanced_pipeline += estimator_selection

# Fit hyperpipe
class_imbalanced_pipeline.fit(X, y)

# Show learning algorithms mean validation results
# print("Comparison on learning algorithms on validation set")
# print(class_imbalanced_pipeline.results_handler.get_mean_of_best_validation_configs_per_estimator())

# # Show feature importances
# print_feature_importances(class_imbalanced_pipeline)

# # View CV splits for debugging
# for k,v in class_imbalanced_pipeline.cross_validation.outer_folds.items():
#     print(v.train_indices)
#     print(v.test_indices)
#     print(len(v.train_indices), len(v.test_indices))
#     print()

# Write other reports to summary file
add_other_report_to_summary(class_imbalanced_pipeline)
# Out:
# 11/06/2025-21:34:51 | Output Folder: ./analysis/participant2_15s\3ClassImbalancedPipline_results_2025-06-11_21-34-51
# =====================================================================================================
# PHOTONAI ANALYSIS: 3ClassImbalancedPipline
# =====================================================================================================
# 11/06/2025-21:34:51 | Preparing data and PHOTONAI objects for analysis...
# 11/06/2025-21:34:51 | Checking input data...
# 11/06/2025-21:34:51 | Running analysis with 172800 samples.
# Found 2 target classes: [0 1]
# Target classes are imbalanced: 97.40104166666667% belongs to 0
# 11/06/2025-21:34:51 | Removing cache files...
#
# *****************************************************************************************************
# Outer Cross validation Fold 1
# *****************************************************************************************************
# 11/06/2025-21:34:51 | Preparing data for outer fold 1...
# 11/06/2025-21:34:51 | Preparing Hyperparameter Optimization...
# 11/06/2025-21:34:51 | Running Dummy Estimator...
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "LogisticRegression__C=2.5542579796475113",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:34:56 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-21:34:56 | Computed configuration 1/150 in 0:00:04.944939
# 11/06/2025-21:34:56 | Performance:             balanced_accuracy - Train: 0.9836, Validation: 0.7149
# 11/06/2025-21:34:56 | Best Performance So Far: balanced_accuracy - Train: 0.9836, Validation: 0.7149
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "LogisticRegression__C=6.481320413049754",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:00 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:00 | Computed configuration 2/150 in 0:00:04.234576
# 11/06/2025-21:35:00 | Performance:             balanced_accuracy - Train: 0.9835, Validation: 0.7145
# 11/06/2025-21:35:00 | Best Performance So Far: balanced_accuracy - Train: 0.9836, Validation: 0.7149
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ],
#     "estimators": [
#         "LogisticRegression__C=2.2731775625532125",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:04 | Computed configuration 3/150 in 0:00:03.900406
# 11/06/2025-21:35:04 | Performance:             balanced_accuracy - Train: 0.9742, Validation: 0.7703
# 11/06/2025-21:35:04 | Best Performance So Far: balanced_accuracy - Train: 0.9742, Validation: 0.7703
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=7.285782123184512",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:05 | Computed configuration 4/150 in 0:00:00.400040
# 11/06/2025-21:35:05 | Performance:             balanced_accuracy - Train: 0.9788, Validation: 0.7677
# 11/06/2025-21:35:05 | Best Performance So Far: balanced_accuracy - Train: 0.9742, Validation: 0.7703
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "LogisticRegression__C=6.696667939532149",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:09 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:09 | Computed configuration 5/150 in 0:00:03.965595
# 11/06/2025-21:35:09 | Performance:             balanced_accuracy - Train: 0.9836, Validation: 0.7147
# 11/06/2025-21:35:09 | Best Performance So Far: balanced_accuracy - Train: 0.9742, Validation: 0.7703
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=6.151208421341622",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:09 | Computed configuration 6/150 in 0:00:00.634503
# 11/06/2025-21:35:09 | Performance:             balanced_accuracy - Train: 0.9753, Validation: 0.7794
# 11/06/2025-21:35:09 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomOverSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=6.437187444229276",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:13 | Computed configuration 7/150 in 0:00:03.948550
# 11/06/2025-21:35:13 | Performance:             balanced_accuracy - Train: 0.9744, Validation: 0.7653
# 11/06/2025-21:35:13 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomOverSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=8.307529733187518",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35

#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:41 | Computed configuration 23/150 in 0:00:00.333643
# 11/06/2025-21:35:41 | Performance:             balanced_accuracy - Train: 0.9733, Validation: 0.7709
# 11/06/2025-21:35:41 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=6.140666603248948",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:42 | Computed configuration 24/150 in 0:00:00.333527
# 11/06/2025-21:35:42 | Performance:             balanced_accuracy - Train: 0.9818, Validation: 0.7686
# 11/06/2025-21:35:42 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=5.607272660235306",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:43 | Computed configuration 25/150 in 0:00:00.337300
# 11/06/2025-21:35:43 | Performance:             balanced_accuracy - Train: 0.9729, Validation: 0.7772
# 11/06/2025-21:35:43 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=5.598490214410598",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:44 | Computed configuration 26/150 in 0:00:00.608210
# 11/06/2025-21:35:44 | Performance:             balanced_accuracy - Train: 0.9744, Validation: 0.7748
# 11/06/2025-21:35:44 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=5.641935939863202",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:44 | Computed configuration 27/150 in 0:00:00.341306
# 11/06/2025-21:35:44 | Performance:             balanced_accuracy - Train: 0.9744, Validation: 0.7784
# 11/06/2025-21:35:44 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=5.646640636166007",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:45 | Computed configuration 28/150 in 0:00:00.333549
# 11/06/2025-21:35:45 | Performance:             balanced_accuracy - Train: 0.9795, Validation: 0.7562
# 11/06/2025-21:35:45 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=5.615495604399805",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:45 | Computed configuration 29/150 in 0:00:00.321396
# 11/06/2025-21:35:45 | Performance:             balanced_accuracy - Train: 0.9715, Validation: 0.7775
# 11/06/2025-21:35:45 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "LogisticRegression__C=5.628128866541596",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-21:35:46 | Computed configuration 30/150 in 0:00:00.327690
# 11/06/2025-21:35:46 | Performance:             balanced_accuracy - Train: 0.9784, Validation: 0.7668
# 11/06/2025-21:35:46 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=7",
#         "DecisionTreeClassifier__min_samples_leaf=3",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:48 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:48 | Computed configuration 31/150 in 0:00:01.550435
# 11/06/2025-21:35:48 | Performance:             balanced_accuracy - Train: 0.9997, Validation: 0.6906
# 11/06/2025-21:35:48 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=20",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:48 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:48 | Computed configuration 32/150 in 0:00:00.399243
# 11/06/2025-21:35:48 | Performance:             balanced_accuracy - Train: 0.9998, Validation: 0.6295
# 11/06/2025-21:35:48 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=30",
#         "DecisionTreeClassifier__min_samples_leaf=9",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:49 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:49 | Computed configuration 33/150 in 0:00:00.416817
# 11/06/2025-21:35:49 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6160
# 11/06/2025-21:35:49 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=25",
#         "DecisionTreeClassifier__min_samples_leaf=25",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:49 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:49 | Computed configuration 34/150 in 0:00:00.060403
# 11/06/2025-21:35:49 | Performance:             balanced_accuracy - Train: 0.9927, Validation: 0.7207
# 11/06/2025-21:35:49 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=6",
#         "DecisionTreeClassifier__min_samples_leaf=20",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:49 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:49 | Computed configuration 35/150 in 0:00:00.387730
# 11/06/2025-21:35:49 | Performance:             balanced_accuracy - Train: 0.9998, Validation: 0.6295
# 11/06/2025-21:35:49 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=12",
#         "DecisionTreeClassifier__min_samples_leaf=22",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:49 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:49 | Computed configuration 36/150 in 0:00:00.050222
# 11/06/2025-21:35:49 | Performance:             balanced_accuracy - Train: 0.9927, Validation: 0.7207
# 11/06/2025-21:35:49 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=25",
#         "DecisionTreeClassifier__min_samples_leaf=23",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:50 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:50 | Computed configuration 37/150 in 0:00:00.383653
# 11/06/2025-21:35:50 | Performance:             balanced_accuracy - Train: 0.9998, Validation: 0.6646
# 11/06/2025-21:35:50 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=8",
#         "DecisionTreeClassifier__min_samples_leaf=8",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:50 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:50 | Computed configuration 38/150 in 0:00:00.400448
# 11/06/2025-21:35:50 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6160
# 11/06/2025-21:35:50 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomOverSampler"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=16",
#         "DecisionTreeClassifier__min_samples_leaf=23",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:50 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:50 | Computed configuration 39/150 in 0:00:00.308839
# 11/06/2025-21:35:50 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6159
# 11/06/2025-21:35:50 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=19",
#         "DecisionTreeClassifier__min_samples_leaf=4",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:52 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:52 | Computed configuration 40/150 in 0:00:01.299981
# 11/06/2025-21:35:52 | Performance:             balanced_accuracy - Train: 0.9996, Validation: 0.6981
# 11/06/2025-21:35:52 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=25",
#         "DecisionTreeClassifier__min_samples_leaf=27",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:52 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:52 | Computed configuration 41/150 in 0:00:00.050193
# 11/06/2025-21:35:52 | Performance:             balanced_accuracy - Train: 0.9927, Validation: 0.7207
# 11/06/2025-21:35:52 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=18",
#         "DecisionTreeClassifier__min_samples_leaf=15",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:52 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:52 | Computed configuration 42/150 in 0:00:00.051935
# 11/06/2025-21:35:52 | Performance:             balanced_accuracy - Train: 0.9952, Validation: 0.7199
# 11/06/2025-21:35:52 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=27",
#         "DecisionTreeClassifier__min_samples_leaf=7",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:54 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:54 | Computed configuration 43/150 in 0:00:01.575833
# 11/06/2025-21:35:54 | Performance:             balanced_accuracy - Train: 0.9990, Validation: 0.6906
# 11/06/2025-21:35:54 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=8",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:56 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:56 | Computed configuration 44/150 in 0:00:01.337322
# 11/06/2025-21:35:56 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.6906
# 11/06/2025-21:35:56 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=8",
#         "DecisionTreeClassifier__min_samples_leaf=9",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:57 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:57 | Computed configuration 45/150 in 0:00:01.334141
# 11/06/2025-21:35:57 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.6908
# 11/06/2025-21:35:57 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=9",
#         "DecisionTreeClassifier__min_samples_leaf=11",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:35:59 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:35:59 | Computed configuration 46/150 in 0:00:01.283441
# 11/06/2025-21:35:59 | Performance:             balanced_accuracy - Train: 0.9987, Validation: 0.6908
# 11/06/2025-21:35:59 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=12",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:01 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:01 | Computed configuration 47/150 in 0:00:01.567038
# 11/06/2025-21:36:01 | Performance:             balanced_accuracy - Train: 0.9986, Validation: 0.6933
# 11/06/2025-21:36:01 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=13",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:03 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:03 | Computed configuration 48/150 in 0:00:01.283530
# 11/06/2025-21:36:03 | Performance:             balanced_accuracy - Train: 0.9986, Validation: 0.6933
# 11/06/2025-21:36:03 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=14",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:04 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:04 | Computed configuration 49/150 in 0:00:01.267360
# 11/06/2025-21:36:04 | Performance:             balanced_accuracy - Train: 0.9985, Validation: 0.6933
# 11/06/2025-21:36:04 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=7",
#         "DecisionTreeClassifier__min_samples_leaf=15",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:06 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:06 | Computed configuration 50/150 in 0:00:01.293460
# 11/06/2025-21:36:06 | Performance:             balanced_accuracy - Train: 0.9985, Validation: 0.6933
# 11/06/2025-21:36:06 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=9",
#         "DecisionTreeClassifier__min_samples_leaf=16",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:07 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:07 | Computed configuration 51/150 in 0:00:00.375837
# 11/06/2025-21:36:07 | Performance:             balanced_accuracy - Train: 0.9998, Validation: 0.6295
# 11/06/2025-21:36:07 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=9",
#         "DecisionTreeClassifier__min_samples_leaf=14",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:08 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:08 | Computed configuration 52/150 in 0:00:01.283629
# 11/06/2025-21:36:08 | Performance:             balanced_accuracy - Train: 0.9985, Validation: 0.6933
# 11/06/2025-21:36:08 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=9",
#         "DecisionTreeClassifier__min_samples_leaf=15",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:10 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:10 | Computed configuration 53/150 in 0:00:01.267018
# 11/06/2025-21:36:10 | Performance:             balanced_accuracy - Train: 0.9985, Validation: 0.6933
# 11/06/2025-21:36:10 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=23",
#         "DecisionTreeClassifier__min_samples_leaf=16",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:11 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:11 | Computed configuration 54/150 in 0:00:00.416997
# 11/06/2025-21:36:11 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6160
# 11/06/2025-21:36:11 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=16",
#         "DecisionTreeClassifier__min_samples_leaf=15",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:12 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:12 | Computed configuration 55/150 in 0:00:01.533778
# 11/06/2025-21:36:12 | Performance:             balanced_accuracy - Train: 0.9985, Validation: 0.6933
# 11/06/2025-21:36:12 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=16",
#         "DecisionTreeClassifier__min_samples_leaf=16",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:13 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:13 | Computed configuration 56/150 in 0:00:00.400426
# 11/06/2025-21:36:13 | Performance:             balanced_accuracy - Train: 0.9998, Validation: 0.6295
# 11/06/2025-21:36:13 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomOverSampler"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=16",
#         "DecisionTreeClassifier__min_samples_leaf=14",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:14 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:14 | Computed configuration 57/150 in 0:00:00.298239
# 11/06/2025-21:36:14 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6159
# 11/06/2025-21:36:14 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=15",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:15 | Skipped further cross validation after fold 2 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:15 | Computed configuration 58/150 in 0:00:01.275752
# 11/06/2025-21:36:15 | Performance:             balanced_accuracy - Train: 0.9985, Validation: 0.6933
# 11/06/2025-21:36:15 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomOverSampler"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=12",
#         "DecisionTreeClassifier__min_samples_leaf=14",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:16 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:16 | Computed configuration 59/150 in 0:00:00.316395
# 11/06/2025-21:36:16 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6159
# 11/06/2025-21:36:16 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=16",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-21:36:17 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-21:36:17 | Computed configuration 60/150 in 0:00:00.383632
# 11/06/2025-21:36:17 | Performance:             balanced_accuracy - Train: 0.9998, Validation: 0.6295
# 11/06/2025-21:36:17 | Best Performance So Far: balanced_accuracy - Train: 0.9753, Validation: 0.7794
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "LinearSVC__C=5.144687945726697",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:36:19 | Computed configuration 61/150 in 0:00:01.263171
# 11/06/2025-21:36:19 | Performance:             balanced_accuracy - Train: 0.9160, Validation: 0.8781
# 11/06/2025-21:36:19 | Best Performance So Far: balanced_accuracy - Train: 0.9160, Validation: 0.8781
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "LinearSVC__C=15.616854434799341",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:36:20 | Computed configuration 62/150 in 0:00:01.250066
# 11/06/2025-21:36:20 | Performance:             balanced_accuracy - Train: 0.9160, Validation: 0.8781
# 11/06/2025-21:36:20 | Best Performance So Far: balanced_accuracy - Train: 0.9160, Validation: 0.8781
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ],
#     "estimators": [
#         "LinearSVC__C=4.395140166808567",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:36:21 | Computed configuration 63/150 in 0:00:01.284534
# 11/06/2025-21:36:21 | Performance:             balanced_accuracy - Train: 0.9614, Validation: 0.8790
# 11/06/2025-21:36:21 | Best Performance So Far: balanced_accuracy - Train: 0.9614, Validation: 0.8790
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "estimators": [
#         "LinearSVC__C=17.762085661825363",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:36:21 | Computed configuration 64/150 in 0:00:00.165661
# 11/06/2025-21:36:21 | Performance:             balanced_accuracy - Train: 0.9628, Validation: 0.8765
# 11/06/2025-21:36:21 | Best Performance So Far: balanced_accuracy - Train: 0.9614, Validation: 0.8790
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "LinearSVC__C=16.191114505419062",
#         "estimator_name=LinearSVC"
#     ]
# }
# 11/06/2025-21:36
| Best Performance So Far: balanced_accuracy - Train: 0.9999, Validation: 0.7217
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.016198981768621196",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:23:47 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:23:47 | Computed configuration 147/150 in 0:00:14.789258
# 11/06/2025-22:23:47 | Performance:             balanced_accuracy - Train: 0.9958, Validation: 0.6897
# 11/06/2025-22:23:47 | Best Performance So Far: balanced_accuracy - Train: 0.9999, Validation: 0.7217
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.016596505230462175",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:24:02 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:24:02 | Computed configuration 148/150 in 0:00:14.566870
# 11/06/2025-22:24:02 | Performance:             balanced_accuracy - Train: 0.9958, Validation: 0.6940
# 11/06/2025-22:24:02 | Best Performance So Far: balanced_accuracy - Train: 0.9999, Validation: 0.7217
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.01676600289716948",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:24:17 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:24:17 | Computed configuration 149/150 in 0:00:14.584474
# 11/06/2025-22:24:17 | Performance:             balanced_accuracy - Train: 0.9958, Validation: 0.6874
# 11/06/2025-22:24:17 | Best Performance So Far: balanced_accuracy - Train: 0.9999, Validation: 0.7217
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.01610629513829049",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:24:32 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:24:32 | Computed configuration 150/150 in 0:00:14.767878
# 11/06/2025-22:24:32 | Performance:             balanced_accuracy - Train: 0.9958, Validation: 0.6907
# 11/06/2025-22:24:32 | Best Performance So Far: balanced_accuracy - Train: 0.9999, Validation: 0.7217
# -----------------------------------------------------------------------------------------------------
# 11/06/2025-22:24:32 | Hyperparameter Optimization finished. Now finding best configuration ....
# 11/06/2025-22:24:32 | 150
# -----------------------------------------------------------------------------------------------------
# BEST_CONFIG
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=20",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# -----------------------------------------------------------------------------------------------------
# VALIDATION PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +-------------------+-------------------+------------------+
# |       METRIC      | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +-------------------+-------------------+------------------+
# | balanced_accuracy |       0.9999      |      0.7217      |
# |      f1_score     |       0.9999      |      0.0880      |
# |      accuracy     |       0.9999      |      0.4665      |
# |     precision     |       1.0000      |      0.0460      |
# |    sensitivity    |       0.9998      |      0.9908      |
# |    specificity    |       1.0000      |      0.4526      |
# |        auc        |       0.9999      |      0.7217      |
# +-------------------+-------------------+------------------+
# 11/06/2025-22:24:34 | Computations in outer fold 5 took 8.623561166666667 minutes.
# 11/06/2025-22:24:34 | Writing results to project folder...
#
# *****************************************************************************************************
# Finished all outer fold computations.
# 11/06/2025-22:25:05 | Now analysing the final results...
# 11/06/2025-22:25:05 | Computing dummy metrics...
# 11/06/2025-22:25:05 | Computing mean and std for all outer fold metrics...
# 11/06/2025-22:25:05 | Find best config across outer folds...
# 11/06/2025-22:25:05 | Save final results...
# 11/06/2025-22:25:05 | Writing results to project folder...
# 11/06/2025-22:25:43 | Prepare Hyperpipe.optimum pipe with best config..
# 11/06/2025-22:25:43 | Fitting best model...
# 11/06/2025-22:26:17 | Saved best model to file.
# 11/06/2025-22:26:17 | Summarizing results...
# 11/06/2025-22:26:17 | Write predictions to files...
# 11/06/2025-22:26:18 | Write summary...
# *****************************************************************************************************
#
# ANALYSIS INFORMATION ================================================================================
# Project Folder: ./analysis/participant2_15s\3ClassImbalancedPipline_results_2025-06-11_21-34-51,
# Computation Time: 2025-06-11 21:34:51.382817 - 2025-06-11 22:25:05.511064
# Duration: 0:50:14.128247
# Optimized for: balanced_accuracy
# Hyperparameter Optimizer: switch
#
# DUMMY RESULTS =======================================================================================
# +-------------------+--+
# | PERFORMANCE DUMMY |  |
# +-------------------+--+
# +-------------------+--+
#
# AVERAGE PERFORMANCE ACROSS OUTER FOLDS ==============================================================
# +-------------------+---------------+--------------+-----------+----------+
# |    Metric Name    | Training Mean | Training Std | Test Mean | Test Std |
# +-------------------+---------------+--------------+-----------+----------+
# | balanced_accuracy |    0.99508    |   0.007491   |  0.752194 | 0.072822 |
# |      f1_score     |    0.995181   |   0.007306   |  0.179842 | 0.186396 |
# |      accuracy     |    0.99508    |   0.007491   |  0.553934 | 0.200428 |
# |     precision     |    0.991067   |   0.013359   |  0.148427 | 0.206229 |
# |    sensitivity    |    0.999472   |   0.00098    |  0.961319 | 0.062361 |
# |    specificity    |    0.990687   |   0.014047   |  0.54307  | 0.207427 |
# |        auc        |    0.99508    |   0.007491   |  0.752194 | 0.072822 |
# +-------------------+---------------+--------------+-----------+----------+
#
# BEST HYPERPARAMETER CONFIGURATION ===================================================================
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.006301171989311478",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
#
#
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | fold # | balanced_accuracy | f1_score | accuracy | precision | sensitivity | specificity |  auc   |                                                                                                           Best Hyperparameter Config                                                                                                          |
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   1*   |       0.8952      |  0.5526  |  0.9499  |   0.5609  |    0.8375   |    0.9529   | 0.8952 | {'ImbalancedDataTransformer': ['method_name=BorderlineSMOTE'], 'estimators': ['GradientBoostingClassifier__loss=exponential', 'GradientBoostingClassifier__learning_rate=0.006301171989311478', 'estimator_name=GradientBoostingClassifier']} |
# |   2    |       0.6900      |  0.0792  |  0.3961  |   0.0412  |    1.0000   |    0.3800   | 0.6900 |                                        {'ImbalancedDataTransformer': ['method_name=RandomOverSampler'], 'estimators': ['LogisticRegression__C=8.307875306631953', 'estimator_name=LogisticRegression']}                                       |
# |   3    |       0.7273      |  0.0891  |  0.4696  |   0.0467  |    0.9992   |    0.4555   | 0.7273 |             {'ImbalancedDataTransformer': ['method_name=RandomUnderSampler'], 'estimators': ['RandomForestClassifier__min_samples_split=5', 'RandomForestClassifier__max_features=sqrt', 'estimator_name=RandomForestClassifier']}            |
# |   4    |       0.7268      |  0.0903  |  0.4875  |   0.0473  |    0.9791   |    0.4744   | 0.7268 |             {'ImbalancedDataTransformer': ['method_name=RandomUnderSampler'], 'estimators': ['RandomForestClassifier__min_samples_split=2', 'RandomForestClassifier__max_features=log2', 'estimator_name=RandomForestClassifier']}            |
# |   5    |       0.7217      |  0.0880  |  0.4665  |   0.0460  |    0.9908   |    0.4526   | 0.7217 |             {'ImbalancedDataTransformer': ['method_name=BorderlineSMOTE'], 'estimators': ['DecisionTreeClassifier__min_samples_split=10', 'DecisionTreeClassifier__min_samples_leaf=20', 'estimator_name=DecisionTreeClassifier']}            |
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# PHOTONAI 2.5.0 ======================================================================================
# Your results are stored in ./analysis/participant2_15s\3ClassImbalancedPipline_results_2025-06-11_21-34-51
# Go to https://explorer.photon-ai.com and upload your photonai_results.json for convenient result visualization!
# For more info and documentation visit https://www.photon-ai.com

# %%
import time
import os
from photonai.base.hyperpipe import OutputSettings

# Save original method
original_update_settings = OutputSettings.update_settings

def patched_update_settings(self, name, timestamp):
    max_retries = 5
    delay = 1  # seconds
    
    for attempt in range(max_retries):
        try:
            original_update_settings(self, name, timestamp)
            break  # success, exit retry loop
        except PermissionError as e:
            print(f"PermissionError on attempt {attempt+1}/{max_retries} when updating settings: {e}")
            if attempt < max_retries - 1:
                time.sleep(delay)
            else:
                print("Max retries reached. Raising the PermissionError.")
                raise

# Apply monkey patch
OutputSettings.update_settings = patched_update_settings

# %% [markdown]
# ## Class Imbalanced + Feature Selection Pipeline

# %%
classifier = LogisticRegression(random_state=4).fit(X, y)

class_imbalanced_feature_selection_pipeline = Hyperpipe('4 - CI and FS Pipeline',
                     outer_cv = StratifiedKFold(n_splits=5, shuffle=False),
                     inner_cv = StratifiedKFold(n_splits=3, shuffle=False),
                     use_test_set = False,
                     metrics = list(metrics.keys()),
                     best_config_metric='balanced_accuracy',
                     optimizer='switch',
                     optimizer_params={'name': 'sk_opt', 'n_configurations': 30},
                     project_folder=f'./analysis/{dataset_type}{user}_{frequency}',
                     cache_folder=f'./cache/{dataset_type}{user}_{frequency}/',
                     verbosity=1,
                     performance_constraints=[MinimumPerformanceConstraint('balanced_accuracy', 0.75, 'mean')])


tested_methods = Categorical(['RandomUnderSampler', 'RandomOverSampler', 'SMOTE', 'BorderlineSMOTE'])
class_imbalanced_feature_selection_pipeline += PipelineElement('ImbalancedDataTransformer',
                           hyperparameters={ 'method_name': tested_methods })

class_imbalanced_feature_selection_pipeline += PipelineElement('RFE', 
                           hyperparameters={
                               'n_features_to_select': IntegerRange(2, (len(columns) - 2))
                           }, estimator=classifier)

class_imbalanced_feature_selection_pipeline += estimator_selection

# Fit hyperpipe
class_imbalanced_feature_selection_pipeline.fit(X, y)

# Show learning algorithms mean validation results

# print("Comparison on learning algorithms on validation set")
# print(class_imbalanced_feature_selection_pipeline.results_handler.get_mean_of_best_validation_configs_per_estimator())

# # Show feature importances
# print_feature_importances(class_imbalanced_feature_selection_pipeline)

# # View CV splits for debugging
# for k,v in class_imbalanced_feature_selection_pipeline.cross_validation.outer_folds.items():
#     print(v.train_indices)
#     print(v.test_indices)
#     print(len(v.train_indices), len(v.test_indices))
#     print()

# Write other reports to summary file
add_other_report_to_summary(class_imbalanced_feature_selection_pipeline)
# Out:
# 11/06/2025-22:26:19 | Output Folder: ./analysis/participant2_15s\4CIandFSPipeline_results_2025-06-11_22-26-19
# =====================================================================================================
# PHOTONAI ANALYSIS: 4CIandFSPipeline
# =====================================================================================================
# 11/06/2025-22:26:19 | Preparing data and PHOTONAI objects for analysis...
# 11/06/2025-22:26:19 | Checking input data...
# 11/06/2025-22:26:19 | Running analysis with 172800 samples.
# Found 2 target classes: [0 1]
# Target classes are imbalanced: 97.40104166666667% belongs to 0
# JsonTransformer was unable to create the .json file.
# 11/06/2025-22:26:19 | Removing cache files...
#
# *****************************************************************************************************
# Outer Cross validation Fold 1
# *****************************************************************************************************
# 11/06/2025-22:26:19 | Preparing data for outer fold 1...
# 11/06/2025-22:26:19 | Preparing Hyperparameter Optimization...
# 11/06/2025-22:26:19 | Running Dummy Estimator...
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=7"
#     ],
#     "estimators": [
#         "LogisticRegression__C=9.754159239683961",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-22:26:27 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=8.401816686109871",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-22:27:54 | Computed configuration 22/150 in 0:00:03.851042
# 11/06/2025-22:27:54 | Performance:             balanced_accuracy - Train: 0.9558, Validation: 0.7541
# 11/06/2025-22:27:54 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=8.541647122968923",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-22:27:59 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-22:27:59 | Computed configuration 23/150 in 0:00:04.350456
# 11/06/2025-22:27:59 | Performance:             balanced_accuracy - Train: 0.9586, Validation: 0.7430
# 11/06/2025-22:27:59 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=4.870452606120578",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-22:28:03 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:03 | Computed configuration 24/150 in 0:00:03.867072
# 11/06/2025-22:28:03 | Performance:             balanced_accuracy - Train: 0.9834, Validation: 0.7164
# 11/06/2025-22:28:03 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=4.273166561042233",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-22:28:07 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:07 | Computed configuration 25/150 in 0:00:03.883729
# 11/06/2025-22:28:07 | Performance:             balanced_accuracy - Train: 0.9826, Validation: 0.7206
# 11/06/2025-22:28:07 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=4.320757151932055",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-22:28:12 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:12 | Computed configuration 26/150 in 0:00:04.300441
# 11/06/2025-22:28:12 | Performance:             balanced_accuracy - Train: 0.9540, Validation: 0.7456
# 11/06/2025-22:28:12 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=8.453954886623453",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-22:28:16 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:16 | Computed configuration 27/150 in 0:00:03.874087
# 11/06/2025-22:28:16 | Performance:             balanced_accuracy - Train: 0.9837, Validation: 0.7119
# 11/06/2025-22:28:16 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=8.468864820495337",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-22:28:20 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:20 | Computed configuration 28/150 in 0:00:03.883763
# 11/06/2025-22:28:20 | Performance:             balanced_accuracy - Train: 0.9836, Validation: 0.7146
# 11/06/2025-22:28:20 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=4.216336040835909",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-22:28:25 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:25 | Computed configuration 29/150 in 0:00:04.350311
# 11/06/2025-22:28:25 | Performance:             balanced_accuracy - Train: 0.9830, Validation: 0.7160
# 11/06/2025-22:28:25 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LogisticRegression__C=9.909839705598378",
#         "estimator_name=LogisticRegression"
#     ]
# }
# 11/06/2025-22:28:29 | Skipped further cross validation after fold 3 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:29 | Computed configuration 30/150 in 0:00:04.000505
# 11/06/2025-22:28:29 | Performance:             balanced_accuracy - Train: 0.9833, Validation: 0.7236
# 11/06/2025-22:28:29 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=7"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=3",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:30 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:30 | Computed configuration 31/150 in 0:00:00.233775
# 11/06/2025-22:28:30 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:28:30 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=4"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=11",
#         "DecisionTreeClassifier__min_samples_leaf=28",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:30 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:30 | Computed configuration 32/150 in 0:00:00.200607
# 11/06/2025-22:28:30 | Performance:             balanced_accuracy - Train: 0.8750, Validation: 0.2551
# 11/06/2025-22:28:30 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=9"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=25",
#         "DecisionTreeClassifier__min_samples_leaf=27",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:30 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:30 | Computed configuration 33/150 in 0:00:00.050016
# 11/06/2025-22:28:30 | Performance:             balanced_accuracy - Train: 0.9476, Validation: 0.3635
# 11/06/2025-22:28:30 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomOverSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=4"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=14",
#         "DecisionTreeClassifier__min_samples_leaf=8",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:30 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:30 | Computed configuration 34/150 in 0:00:00.199859
# 11/06/2025-22:28:30 | Performance:             balanced_accuracy - Train: 0.8750, Validation: 0.3193
# 11/06/2025-22:28:30 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=6"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=5",
#         "DecisionTreeClassifier__min_samples_leaf=2",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:30 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:30 | Computed configuration 35/150 in 0:00:00.233228
# 11/06/2025-22:28:30 | Performance:             balanced_accuracy - Train: 0.8750, Validation: 0.1909
# 11/06/2025-22:28:30 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=7"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=11",
#         "DecisionTreeClassifier__min_samples_leaf=8",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:30 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:30 | Computed configuration 36/150 in 0:00:00.051700
# 11/06/2025-22:28:30 | Performance:             balanced_accuracy - Train: 0.8727, Validation: 0.3193
# 11/06/2025-22:28:30 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=10"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=4",
#         "DecisionTreeClassifier__min_samples_leaf=16",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:31 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:31 | Computed configuration 37/150 in 0:00:00.366851
# 11/06/2025-22:28:31 | Performance:             balanced_accuracy - Train: 0.9923, Validation: 0.2507
# 11/06/2025-22:28:31 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=10"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=19",
#         "DecisionTreeClassifier__min_samples_leaf=4",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:31 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:31 | Computed configuration 38/150 in 0:00:00.383311
# 11/06/2025-22:28:31 | Performance:             balanced_accuracy - Train: 0.9991, Validation: 0.3630
# 11/06/2025-22:28:31 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=10",
#         "DecisionTreeClassifier__min_samples_leaf=21",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:31 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:31 | Computed configuration 39/150 in 0:00:00.052938
# 11/06/2025-22:28:31 | Performance:             balanced_accuracy - Train: 0.8727, Validation: 0.6484
# 11/06/2025-22:28:31 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=3"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=2",
#         "DecisionTreeClassifier__min_samples_leaf=15",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:31 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:31 | Computed configuration 40/150 in 0:00:00.054473
# 11/06/2025-22:28:31 | Performance:             balanced_accuracy - Train: 0.8727, Validation: 0.6484
# 11/06/2025-22:28:31 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomOverSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=4",
#         "DecisionTreeClassifier__min_samples_leaf=22",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:40 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:40 | Computed configuration 41/150 in 0:00:08.300759
# 11/06/2025-22:28:40 | Performance:             balanced_accuracy - Train: 0.8750, Validation: 0.6484
# 11/06/2025-22:28:40 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=4",
#         "DecisionTreeClassifier__min_samples_leaf=9",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:48 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:48 | Computed configuration 42/150 in 0:00:08.217452
# 11/06/2025-22:28:48 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:28:48 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=4"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=2",
#         "DecisionTreeClassifier__min_samples_leaf=9",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:57 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:57 | Computed configuration 43/150 in 0:00:07.767727
# 11/06/2025-22:28:57 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:28:57 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=10"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=5",
#         "DecisionTreeClassifier__min_samples_leaf=4",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:28:57 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:28:57 | Computed configuration 44/150 in 0:00:00.356281
# 11/06/2025-22:28:57 | Performance:             balanced_accuracy - Train: 0.9992, Validation: 0.3535
# 11/06/2025-22:28:57 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=3"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=2",
#         "DecisionTreeClassifier__min_samples_leaf=11",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:05 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:05 | Computed configuration 45/150 in 0:00:08.000158
# 11/06/2025-22:29:05 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:05 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=3"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=2",
#         "DecisionTreeClassifier__min_samples_leaf=9",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:06 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:06 | Computed configuration 46/150 in 0:00:00.216317
# 11/06/2025-22:29:06 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:06 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=3"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=5",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:06 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:06 | Computed configuration 47/150 in 0:00:00.216894
# 11/06/2025-22:29:06 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:06 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=8",
#         "DecisionTreeClassifier__min_samples_leaf=8",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:07 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:07 | Computed configuration 48/150 in 0:00:00.199663
# 11/06/2025-22:29:07 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:07 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=11",
#         "DecisionTreeClassifier__min_samples_leaf=10",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:07 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:07 | Computed configuration 49/150 in 0:00:00.200806
# 11/06/2025-22:29:07 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:07 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=3"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=8",
#         "DecisionTreeClassifier__min_samples_leaf=11",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:08 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:08 | Computed configuration 50/150 in 0:00:00.216385
# 11/06/2025-22:29:08 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:08 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=11",
#         "DecisionTreeClassifier__min_samples_leaf=7",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:08 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:09 | Computed configuration 51/150 in 0:00:00.200190
# 11/06/2025-22:29:09 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:09 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=4"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=11",
#         "DecisionTreeClassifier__min_samples_leaf=30",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:09 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:09 | Computed configuration 52/150 in 0:00:00.209257
# 11/06/2025-22:29:09 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:09 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=3"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=8",
#         "DecisionTreeClassifier__min_samples_leaf=6",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:10 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:10 | Computed configuration 53/150 in 0:00:00.200172
# 11/06/2025-22:29:10 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:10 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=3"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=11",
#         "DecisionTreeClassifier__min_samples_leaf=6",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:10 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:10 | Computed configuration 54/150 in 0:00:00.200414
# 11/06/2025-22:29:10 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:10 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=3",
#         "DecisionTreeClassifier__min_samples_leaf=8",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:11 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:11 | Computed configuration 55/150 in 0:00:00.183518
# 11/06/2025-22:29:11 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:11 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=4"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=5",
#         "DecisionTreeClassifier__min_samples_leaf=4",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:11 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:11 | Computed configuration 56/150 in 0:00:00.216396
# 11/06/2025-22:29:11 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:11 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=5"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=2",
#         "DecisionTreeClassifier__min_samples_leaf=21",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:12 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:12 | Computed configuration 57/150 in 0:00:00.224698
# 11/06/2025-22:29:12 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.6527
# 11/06/2025-22:29:12 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=8",
#         "DecisionTreeClassifier__min_samples_leaf=9",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:12 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:12 | Computed configuration 58/150 in 0:00:00.200263
# 11/06/2025-22:29:12 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:12 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=8",
#         "DecisionTreeClassifier__min_samples_leaf=7",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:13 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:13 | Computed configuration 59/150 in 0:00:00.184755
# 11/06/2025-22:29:13 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:13 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "DecisionTreeClassifier__min_samples_split=27",
#         "DecisionTreeClassifier__min_samples_leaf=9",
#         "estimator_name=DecisionTreeClassifier"
#     ]
# }
# 11/06/2025-22:29:13 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:29:13 | Computed configuration 60/150 in 0:00:00.200353
# 11/06/2025-22:29:13 | Performance:             balanced_accuracy - Train: 0.9372, Validation: 0.7169
# 11/06/2025-22:29:13 | Best Performance So Far: balanced_accuracy - Train: 0.9558, Validation: 0.7541
# ...
# 11/06/2025-22:57:38 | Computed configuration 141/150 in 0:00:00.216802
# 11/06/2025-22:57:38 | Performance:             balanced_accuracy - Train: 0.9478, Validation: 0.5763
# 11/06/2025-22:57:38 | Best Performance So Far: balanced_accuracy - Train: 0.6537, Validation: 0.6911
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.0032525400190715264",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:57:38 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:57:38 | Computed configuration 142/150 in 0:00:00.200180
# 11/06/2025-22:57:38 | Performance:             balanced_accuracy - Train: 0.7503, Validation: 0.6911
# 11/06/2025-22:57:38 | Best Performance So Far: balanced_accuracy - Train: 0.6537, Validation: 0.6911
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.0041090775365159515",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:57:39 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:57:39 | Computed configuration 143/150 in 0:00:00.183556
# 11/06/2025-22:57:39 | Performance:             balanced_accuracy - Train: 0.7503, Validation: 0.6911
# 11/06/2025-22:57:39 | Best Performance So Far: balanced_accuracy - Train: 0.6537, Validation: 0.6911
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.5486911364790189",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:57:39 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:57:39 | Computed configuration 144/150 in 0:00:00.192314
# 11/06/2025-22:57:39 | Performance:             balanced_accuracy - Train: 0.7503, Validation: 0.6911
# 11/06/2025-22:57:39 | Best Performance So Far: balanced_accuracy - Train: 0.6537, Validation: 0.6911
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.0039496526137284505",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:57:40 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:57:40 | Computed configuration 145/150 in 0:00:00.179568
# 11/06/2025-22:57:40 | Performance:             balanced_accuracy - Train: 0.7503, Validation: 0.6911
# 11/06/2025-22:57:40 | Best Performance So Far: balanced_accuracy - Train: 0.6537, Validation: 0.6911
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.33222949933503637",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:57:40 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:57:40 | Computed configuration 146/150 in 0:00:00.183471
# 11/06/2025-22:57:40 | Performance:             balanced_accuracy - Train: 0.7503, Validation: 0.6911
# 11/06/2025-22:57:40 | Best Performance So Far: balanced_accuracy - Train: 0.6537, Validation: 0.6911
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.004623072560355012",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:57:41 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:57:41 | Computed configuration 147/150 in 0:00:00.200150
# 11/06/2025-22:57:41 | Performance:             balanced_accuracy - Train: 0.7503, Validation: 0.6911
# 11/06/2025-22:57:41 | Best Performance So Far: balanced_accuracy - Train: 0.6537, Validation: 0.6911
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.004410281841383554",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:57:41 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:57:41 | Computed configuration 148/150 in 0:00:00.183449
# 11/06/2025-22:57:41 | Performance:             balanced_accuracy - Train: 0.7503, Validation: 0.6911
# 11/06/2025-22:57:41 | Best Performance So Far: balanced_accuracy - Train: 0.6537, Validation: 0.6911
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.004722640882992783",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:57:42 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:57:42 | Computed configuration 149/150 in 0:00:00.183420
# 11/06/2025-22:57:42 | Performance:             balanced_accuracy - Train: 0.7503, Validation: 0.6911
# 11/06/2025-22:57:42 | Best Performance So Far: balanced_accuracy - Train: 0.6537, Validation: 0.6911
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "GradientBoostingClassifier__loss=exponential",
#         "GradientBoostingClassifier__learning_rate=0.004641540959753896",
#         "estimator_name=GradientBoostingClassifier"
#     ]
# }
# 11/06/2025-22:57:42 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:57:42 | Computed configuration 150/150 in 0:00:00.200097
# 11/06/2025-22:57:42 | Performance:             balanced_accuracy - Train: 0.7503, Validation: 0.6911
# 11/06/2025-22:57:42 | Best Performance So Far: balanced_accuracy - Train: 0.6537, Validation: 0.6911
# -----------------------------------------------------------------------------------------------------
# 11/06/2025-22:57:42 | Hyperparameter Optimization finished. Now finding best configuration ....
# 11/06/2025-22:57:42 | 150
# -----------------------------------------------------------------------------------------------------
# BEST_CONFIG
# -----------------------------------------------------------------------------------------------------
# {
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ],
#     "RFE": [
#         "n_features_to_select=2"
#     ],
#     "estimators": [
#         "LogisticRegression__C=8.796603687235287",
#         "estimator_name=LogisticRegression"
#     ]
# }
# -----------------------------------------------------------------------------------------------------
# VALIDATION PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +-------------------+-------------------+------------------+
# |       METRIC      | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +-------------------+-------------------+------------------+
# | balanced_accuracy |       0.6537      |      0.6911      |
# |      f1_score     |       0.7303      |      0.0795      |
# |      accuracy     |       0.6537      |      0.3982      |
# |     precision     |       0.5980      |      0.0414      |
# |    sensitivity    |       0.9378      |      1.0000      |
# |    specificity    |       0.3695      |      0.3822      |
# |        auc        |       0.6537      |      0.6911      |
# +-------------------+-------------------+------------------+
# 11/06/2025-22:57:43 | Computations in outer fold 5 took 3.9658710166666666 minutes.
# 11/06/2025-22:57:43 | Writing results to project folder...
#
# *****************************************************************************************************
# Finished all outer fold computations.
# 11/06/2025-22:58:12 | Now analysing the final results...
# 11/06/2025-22:58:12 | Computing dummy metrics...
# 11/06/2025-22:58:12 | Computing mean and std for all outer fold metrics...
# 11/06/2025-22:58:12 | Find best config across outer folds...
# 11/06/2025-22:58:12 | Save final results...
# 11/06/2025-22:58:12 | Writing results to project folder...
# 11/06/2025-22:58:43 | Prepare Hyperpipe.optimum pipe with best config..
# 11/06/2025-22:58:43 | Fitting best model...
# 11/06/2025-22:58:46 | Saved best model to file.
# 11/06/2025-22:58:46 | Summarizing results...
# 11/06/2025-22:58:46 | Write predictions to files...
# 11/06/2025-22:58:47 | Write summary...
# *****************************************************************************************************
#
# ANALYSIS INFORMATION ================================================================================
# Project Folder: ./analysis/participant2_15s\4CIandFSPipeline_results_2025-06-11_22-26-19,
# Computation Time: 2025-06-11 22:26:19.698718 - 2025-06-11 22:58:12.861496
# Duration: 0:31:53.162778
# Optimized for: balanced_accuracy
# Hyperparameter Optimizer: switch
#
# DUMMY RESULTS =======================================================================================
# +-------------------+--+
# | PERFORMANCE DUMMY |  |
# +-------------------+--+
# +-------------------+--+
#
# AVERAGE PERFORMANCE ACROSS OUTER FOLDS ==============================================================
# +-------------------+---------------+--------------+-----------+----------+
# |    Metric Name    | Training Mean | Training Std | Test Mean | Test Std |
# +-------------------+---------------+--------------+-----------+----------+
# | balanced_accuracy |    0.885164   |   0.116446   |  0.76124  | 0.061541 |
# |      f1_score     |    0.900912   |   0.086559   |  0.190583 | 0.183009 |
# |      accuracy     |    0.885164   |   0.116446   |  0.620063 | 0.189581 |
# |     precision     |    0.860656   |   0.133041   |  0.144965 | 0.184587 |
# |    sensitivity    |    0.95921    |   0.042917   |  0.910154 | 0.083106 |
# |    specificity    |    0.811118   |    0.2224    |  0.612327 | 0.196701 |
# |        auc        |    0.885164   |   0.116446   |  0.76124  | 0.061541 |
# +-------------------+---------------+--------------+-----------+----------+
#
# BEST HYPERPARAMETER CONFIGURATION ===================================================================
# {
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ],
#     "RFE": [
#         "n_features_to_select=12"
#     ],
#     "estimators": [
#         "LinearSVC__C=6.872045089038763",
#         "estimator_name=LinearSVC"
#     ]
# }
#
#
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | fold # | balanced_accuracy | f1_score | accuracy | precision | sensitivity | specificity |  auc   |                                                                                                                 Best Hyperparameter Config                                                                                                                |
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   1*   |       0.8766      |  0.5556  |  0.9559  |   0.5138  |    0.7929   |    0.9603   | 0.8766 |                                      {'ImbalancedDataTransformer': ['method_name=BorderlineSMOTE'], 'RFE': ['n_features_to_select=12'], 'estimators': ['LinearSVC__C=6.872045089038763', 'estimator_name=LinearSVC']}                                     |
# |   2    |       0.7467      |  0.1032  |  0.5866  |   0.0547  |    0.9156   |    0.5778   | 0.7467 |   {'ImbalancedDataTransformer': ['method_name=BorderlineSMOTE'], 'RFE': ['n_features_to_select=7'], 'estimators': ['RandomForestClassifier__min_samples_split=3', 'RandomForestClassifier__max_features=log2', 'estimator_name=RandomForestClassifier']}  |
# |   3    |       0.7494      |  0.1208  |  0.6613  |   0.0657  |    0.8422   |    0.6565   | 0.7494 | {'ImbalancedDataTransformer': ['method_name=BorderlineSMOTE'], 'RFE': ['n_features_to_select=9'], 'estimators': ['DecisionTreeClassifier__min_samples_split=22', 'DecisionTreeClassifier__min_samples_leaf=29', 'estimator_name=DecisionTreeClassifier']} |
# |   4    |       0.7424      |  0.0938  |  0.4982  |   0.0492  |    1.0000   |    0.4848   | 0.7424 |  {'ImbalancedDataTransformer': ['method_name=RandomOverSampler'], 'RFE': ['n_features_to_select=5'], 'estimators': ['RandomForestClassifier__min_samples_split=3', 'RandomForestClassifier__max_features=log2', 'estimator_name=RandomForestClassifier']} |
# |   5    |       0.6911      |  0.0795  |  0.3982  |   0.0414  |    1.0000   |    0.3822   | 0.6911 |                            {'ImbalancedDataTransformer': ['method_name=RandomUnderSampler'], 'RFE': ['n_features_to_select=2'], 'estimators': ['LogisticRegression__C=8.796603687235287', 'estimator_name=LogisticRegression']}                           |
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# PHOTONAI 2.5.0 ======================================================================================
# Your results are stored in ./analysis/participant2_15s\4CIandFSPipeline_results_2025-06-11_22-26-19
# Go to https://explorer.photon-ai.com and upload your photonai_results.json for convenient result visualization!
# For more info and documentation visit https://www.photon-ai.com

# %% [markdown]
# ## Final Pipeline

# %% [markdown]
# ### CI GB

# %%
final_pipeline1 = Hyperpipe('5 - Final Pipeline CI GB',
                    outer_cv = StratifiedKFold(n_splits=5, shuffle=False),
                    inner_cv = StratifiedKFold(n_splits=3, shuffle=False),
                    use_test_set = True,
                    metrics = list(metrics.keys()),
                    best_config_metric='balanced_accuracy',
                    optimizer='sk_opt',
                    optimizer_params={'n_configurations': 30},
                    project_folder=f'./analysis/{dataset_type}{user}_{frequency}',
                    cache_folder=f'./cache/{dataset_type}{user}_{frequency}/',
                    verbosity=1,
                    performance_constraints=[MinimumPerformanceConstraint('balanced_accuracy', 0.75, 'mean')])

tested_methods = Categorical(['RandomUnderSampler', 'RandomOverSampler', 'SMOTE', 'BorderlineSMOTE'])
final_pipeline1 += PipelineElement('ImbalancedDataTransformer',
                           hyperparameters={ 'method_name': tested_methods })

final_pipeline1 += PipelineElement('GradientBoostingClassifier', 
                            hyperparameters={
                                'loss': ['deviance', 'exponential'],
                                'learning_rate': FloatRange(0.001, 1, 'logspace')
                            }, random_state=4)

# Fit hyperpipe
final_pipeline1.fit(X, y)

# Show learning algorithms mean validation results
# print("Comparison on learning algorithms on validation set")
# print(final_pipeline1.results_handler.get_mean_of_best_validation_configs_per_estimator())

# # Show feature importances
# print_feature_importances(final_pipeline1)

# # View CV splits for debugging
# for k,v in final_pipeline1.cross_validation.outer_folds.items():
#     print(v.train_indices)
#     print(v.test_indices)
#     print(len(v.train_indices), len(v.test_indices))
#     print()

# Write other reports to summary file
add_other_report_to_summary(final_pipeline1, with_estimator_comparison=False)

# Show confusion matrix
plot_confusion_matrix_from_pipeline(final_pipeline1)
# Out:
# 11/06/2025-22:58:47 | Output Folder: ./analysis/participant2_15s\5FinalPipelineCIGB_results_2025-06-11_22-58-47
# =====================================================================================================
# PHOTONAI ANALYSIS: 5FinalPipelineCIGB
# =====================================================================================================
# 11/06/2025-22:58:47 | Preparing data and PHOTONAI objects for analysis...
# 11/06/2025-22:58:47 | Checking input data...
# 11/06/2025-22:58:47 | Running analysis with 172800 samples.
# Found 2 target classes: [0 1]
# Target classes are imbalanced: 97.40104166666667% belongs to 0
# 11/06/2025-22:58:47 | Removing cache files...
#
# *****************************************************************************************************
# Outer Cross validation Fold 1
# *****************************************************************************************************
# 11/06/2025-22:58:47 | Preparing data for outer fold 1...
# 11/06/2025-22:58:47 | Preparing Hyperparameter Optimization...
# 11/06/2025-22:58:47 | Running Dummy Estimator...
# +-------------------+--------+
# | PERFORMANCE DUMMY |        |
# +-------------------+--------+
# | balanced_accuracy | 0.5000 |
# |      f1_score     | 0.0000 |
# |      accuracy     | 0.9740 |
# |     precision     | 0.0000 |
# |    sensitivity    | 0.0000 |
# |    specificity    | 1.0000 |
# |        auc        | 0.5000 |
# +-------------------+--------+
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=deviance",
#         "learning_rate=0.3688610897684593"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ]
# }
# The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# Traceback (most recent call last):
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 154, in fit
#     curr_test_fold, curr_train_fold = InnerFoldManager.fit_and_score(job_data)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 350, in fit_and_score
#     pipe.fit(job.train_data.X, job.train_data.y, **job.train_data.cv_kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_pipeline.py", line 162, in fit
#     self._final_estimator.fit(X, y, **kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_elements.py", line 431, in fit
#     obj.fit(X, y)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
#
# The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.0026570059126609985"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ]
# }
# Traceback (most recent call last):
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 154, in fit
#     curr_test_fold, curr_train_fold = InnerFoldManager.fit_and_score(job_data)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 350, in fit_and_score
#     pipe.fit(job.train_data.X, job.train_data.y, **job.train_data.cv_kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_pipeline.py", line 162, in fit
#     self._final_estimator.fit(X, y, **kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_elements.py", line 431, in fit
#     obj.fit(X, y)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# 11/06/2025-22:59:05 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:59:05 | Computed configuration 2/30 in 0:00:17.434389
# 11/06/2025-22:59:05 | Performance:             balanced_accuracy - Train: 0.9940, Validation: 0.7159
# 11/06/2025-22:59:05 | Best Performance So Far: balanced_accuracy - Train: 0.9940, Validation: 0.7159
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.5123132299514567"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-22:59:05 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:59:05 | Computed configuration 3/30 in 0:00:00.533172
# 11/06/2025-22:59:05 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6664
# 11/06/2025-22:59:05 | Best Performance So Far: balanced_accuracy - Train: 0.9940, Validation: 0.7159
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=deviance",
#         "learning_rate=0.05212780929227985"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ]
# }
# The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# Traceback (most recent call last):
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 154, in fit
#     curr_test_fold, curr_train_fold = InnerFoldManager.fit_and_score(job_data)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 350, in fit_and_score
#     pipe.fit(job.train_data.X, job.train_data.y, **job.train_data.cv_kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_pipeline.py", line 162, in fit
#     self._final_estimator.fit(X, y, **kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_elements.py", line 431, in fit
#     obj.fit(X, y)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
#
# The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.014972646975855559"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomOverSampler"
#     ]
# }
# Traceback (most recent call last):
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 154, in fit
#     curr_test_fold, curr_train_fold = InnerFoldManager.fit_and_score(job_data)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 350, in fit_and_score
#     pipe.fit(job.train_data.X, job.train_data.y, **job.train_data.cv_kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_pipeline.py", line 162, in fit
#     self._final_estimator.fit(X, y, **kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_elements.py", line 431, in fit
#     obj.fit(X, y)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# 11/06/2025-22:59:16 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-22:59:16 | Computed configuration 5/30 in 0:00:10.600641
# 11/06/2025-22:59:16 | Performance:             balanced_accuracy - Train: 0.9940, Validation: 0.7171
# 11/06/2025-22:59:16 | Best Performance So Far: balanced_accuracy - Train: 0.9940, Validation: 0.7171
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.006301171989311478"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ]
# }
# 11/06/2025-23
PERFORMANCE TRAIN | PERFORMANCE TEST |
# +-------------------+-------------------+------------------+
# | balanced_accuracy |       0.9813      |      0.8953      |
# |      f1_score     |       0.9818      |      0.5528      |
# |      accuracy     |       0.9813      |      0.9499      |
# |     precision     |       0.9656      |      0.5609      |
# |    sensitivity    |       0.9989      |      0.8378      |
# |    specificity    |       0.9638      |      0.9529      |
# |        auc        |       0.9813      |      0.8953      |
# +-------------------+-------------------+------------------+
# 11/06/2025-23:15:51 | Calculating best model performance on test set...
# -----------------------------------------------------------------------------------------------------
# TEST PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +-------------------+-------------------+------------------+
# |       METRIC      | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +-------------------+-------------------+------------------+
# | balanced_accuracy |       0.9720      |      0.5636      |
# |      f1_score     |       0.9727      |      0.0576      |
# |      accuracy     |       0.9720      |      0.1499      |
# |     precision     |       0.9480      |      0.0297      |
# |    sensitivity    |       0.9986      |      1.0000      |
# |    specificity    |       0.9453      |      0.1273      |
# |        auc        |       0.9720      |      0.5636      |
# +-------------------+-------------------+------------------+
# 11/06/2025-23:15:52 | Computations in outer fold 1 took 17.0799009 minutes.
# 11/06/2025-23:15:52 | Writing results to project folder...
#
# *****************************************************************************************************
# Outer Cross validation Fold 2
# *****************************************************************************************************
# 11/06/2025-23:16:15 | Preparing data for outer fold 2...
# 11/06/2025-23:16:15 | Preparing Hyperparameter Optimization...
# 11/06/2025-23:16:15 | Running Dummy Estimator...
# +-------------------+--------+
# | PERFORMANCE DUMMY |        |
# +-------------------+--------+
# | balanced_accuracy | 0.5000 |
# |      f1_score     | 0.0000 |
# |      accuracy     | 0.9740 |
# |     precision     | 0.0000 |
# |    sensitivity    | 0.0000 |
# |    specificity    | 1.0000 |
# |        auc        | 0.5000 |
# +-------------------+--------+
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=deviance",
#         "learning_rate=0.3688610897684593"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ]
# }
# The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# Traceback (most recent call last):
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 154, in fit
#     curr_test_fold, curr_train_fold = InnerFoldManager.fit_and_score(job_data)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 350, in fit_and_score
#     pipe.fit(job.train_data.X, job.train_data.y, **job.train_data.cv_kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_pipeline.py", line 162, in fit
#     self._final_estimator.fit(X, y, **kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_elements.py", line 431, in fit
#     obj.fit(X, y)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
#
# The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.0026570059126609985"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ]
# }
# Traceback (most recent call last):
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 154, in fit
#     curr_test_fold, curr_train_fold = InnerFoldManager.fit_and_score(job_data)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 350, in fit_and_score
#     pipe.fit(job.train_data.X, job.train_data.y, **job.train_data.cv_kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_pipeline.py", line 162, in fit
#     self._final_estimator.fit(X, y, **kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_elements.py", line 431, in fit
#     obj.fit(X, y)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# 11/06/2025-23:16:33 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:16:33 | Computed configuration 2/30 in 0:00:17.265118
# 11/06/2025-23:16:33 | Performance:             balanced_accuracy - Train: 0.9940, Validation: 0.5650
# 11/06/2025-23:16:33 | Best Performance So Far: balanced_accuracy - Train: 0.9940, Validation: 0.5650
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.5123132299514567"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:16:33 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:16:33 | Computed configuration 3/30 in 0:00:00.538301
# 11/06/2025-23:16:33 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.5605
# 11/06/2025-23:16:33 | Best Performance So Far: balanced_accuracy - Train: 0.9940, Validation: 0.5650
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=deviance",
#         "learning_rate=0.05212780929227985"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ]
# }
# The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# Traceback (most recent call last):
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 154, in fit
#     curr_test_fold, curr_train_fold = InnerFoldManager.fit_and_score(job_data)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 350, in fit_and_score
#     pipe.fit(job.train_data.X, job.train_data.y, **job.train_data.cv_kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_pipeline.py", line 162, in fit
#     self._final_estimator.fit(X, y, **kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_elements.py", line 431, in fit
#     obj.fit(X, y)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
#
# The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.014972646975855559"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomOverSampler"
#     ]
# }
# Traceback (most recent call last):
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 154, in fit
#     curr_test_fold, curr_train_fold = InnerFoldManager.fit_and_score(job_data)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 350, in fit_and_score
#     pipe.fit(job.train_data.X, job.train_data.y, **job.train_data.cv_kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_pipeline.py", line 162, in fit
#     self._final_estimator.fit(X, y, **kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_elements.py", line 431, in fit
#     obj.fit(X, y)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# 11/06/2025-23:16:44 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:16:44 | Computed configuration 5/30 in 0:00:10.833278
# 11/06/2025-23:16:44 | Performance:             balanced_accuracy - Train: 0.9940, Validation: 0.5646
# 11/06/2025-23:16:44 | Best Performance So Far: balanced_accuracy - Train: 0.9940, Validation: 0.5650
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.006301171989311478"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ]
# }
# 11/06/2025-23:17:00 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:17:00 | Computed configuration 6/30 in 0:00:15.751072
# 11/06/2025-23:17:00 | Performance:             balanced_accuracy - Train: 0.9961, Validation: 0.6275
# 11/06/2025-23:17:00 | Best Performance So Far: balanced_accuracy - Train: 0.9961, Validation: 0.6275
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.001140444703947033"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=SMOTE"
#     ]
# }
# 11/06/2025-23:17:17 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:17:17 | Computed configuration 7/30 in 0:00:17.084380
# 11/06/2025-23:17:17 | Performance:             balanced_accuracy - Train: 0.9940, Validation: 0.5650
# 11/06/2025-23:17:17 | Best Performance So Far: balanced_accuracy - Train: 0.9961, Validation: 0.6275
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.021829691199987622"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:17:17 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:17:17 | Computed configuration 8/30 in 0:00:00.450653
# 11/06/2025-23:17:17 | Performance:             balanced_accuracy - Train: 0.9942, Validation: 0.6596
# 11/06/2025-23:17:17 | Best Performance So Far: balanced_accuracy - Train: 0.9942, Validation: 0.6596
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=deviance",
#         "learning_rate=0.0033696415113161483"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomOverSampler"
#     ]
# }
# The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# Traceback (most recent call last):
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 154, in fit
#     curr_test_fold, curr_train_fold = InnerFoldManager.fit_and_score(job_data)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 350, in fit_and_score
#     pipe.fit(job.train_data.X, job.train_data.y, **job.train_data.cv_kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_pipeline.py", line 162, in fit
#     self._final_estimator.fit(X, y, **kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_elements.py", line 431, in fit
#     obj.fit(X, y)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
#
# The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.5962926931408471"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ]
# }
# Traceback (most recent call last):
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 154, in fit
#     curr_test_fold, curr_train_fold = InnerFoldManager.fit_and_score(job_data)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\processing\inner_folds.py", line 350, in fit_and_score
#     pipe.fit(job.train_data.X, job.train_data.y, **job.train_data.cv_kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_pipeline.py", line 162, in fit
#     self._final_estimator.fit(X, y, **kwargs)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\photonai\base\photon_elements.py", line 431, in fit
#     obj.fit(X, y)
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Shared-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
# ...
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.695387927798795"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:47 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:47 | Computed configuration 20/30 in 0:00:00.233417
# 11/06/2025-23:33:47 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6200
# 11/06/2025-23:33:47 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6949
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.6943681145159899"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:48 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:48 | Computed configuration 21/30 in 0:00:00.230894
# 11/06/2025-23:33:48 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6373
# 11/06/2025-23:33:48 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6949
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.6794914470667958"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:48 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:48 | Computed configuration 22/30 in 0:00:00.233441
# 11/06/2025-23:33:48 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6758
# 11/06/2025-23:33:48 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6949
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.7059054519526485"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:49 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:49 | Computed configuration 23/30 in 0:00:00.233488
# 11/06/2025-23:33:49 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6770
# 11/06/2025-23:33:49 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6949
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.7107903440328458"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:49 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:49 | Computed configuration 24/30 in 0:00:00.233767
# 11/06/2025-23:33:49 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6287
# 11/06/2025-23:33:49 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6949
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.5385232668929524"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:50 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:50 | Computed configuration 25/30 in 0:00:00.266757
# 11/06/2025-23:33:50 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6972
# 11/06/2025-23:33:50 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6972
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.5419978081071275"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:50 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:50 | Computed configuration 26/30 in 0:00:00.271737
# 11/06/2025-23:33:50 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6274
# 11/06/2025-23:33:50 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6972
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.5306274976175681"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:51 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:51 | Computed configuration 27/30 in 0:00:00.266923
# 11/06/2025-23:33:51 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6764
# 11/06/2025-23:33:51 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6972
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.5284721512548405"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:51 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:51 | Computed configuration 28/30 in 0:00:00.250309
# 11/06/2025-23:33:51 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6750
# 11/06/2025-23:33:51 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6972
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.5355680123291423"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:52 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:52 | Computed configuration 29/30 in 0:00:00.266808
# 11/06/2025-23:33:52 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6754
# 11/06/2025-23:33:52 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6972
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.4869502550473524"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# 11/06/2025-23:33:52 | Skipped further cross validation after fold 1 due to performance constraints in balanced_accuracy
# 11/06/2025-23:33:52 | Computed configuration 30/30 in 0:00:00.286326
# 11/06/2025-23:33:52 | Performance:             balanced_accuracy - Train: 1.0000, Validation: 0.6335
# 11/06/2025-23:33:52 | Best Performance So Far: balanced_accuracy - Train: 1.0000, Validation: 0.6972
# -----------------------------------------------------------------------------------------------------
# 11/06/2025-23:33:53 | Hyperparameter Optimization finished. Now finding best configuration ....
# 11/06/2025-23:33:53 | 30
# -----------------------------------------------------------------------------------------------------
# BEST_CONFIG
# -----------------------------------------------------------------------------------------------------
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.5385232668929524"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=RandomUnderSampler"
#     ]
# }
# -----------------------------------------------------------------------------------------------------
# VALIDATION PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +-------------------+-------------------+------------------+
# |       METRIC      | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +-------------------+-------------------+------------------+
# | balanced_accuracy |       1.0000      |      0.6972      |
# |      f1_score     |       1.0000      |      0.0809      |
# |      accuracy     |       1.0000      |      0.4101      |
# |     precision     |       1.0000      |      0.0422      |
# |    sensitivity    |       1.0000      |      1.0000      |
# |    specificity    |       1.0000      |      0.3944      |
# |        auc        |       1.0000      |      0.6972      |
# +-------------------+-------------------+------------------+
# 11/06/2025-23:33:53 | Calculating best model performance on test set...
# -----------------------------------------------------------------------------------------------------
# TEST PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +-------------------+-------------------+------------------+
# |       METRIC      | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +-------------------+-------------------+------------------+
# | balanced_accuracy |       0.9857      |      0.6897      |
# |      f1_score     |       0.9859      |      0.5077      |
# |      accuracy     |       0.9857      |      0.9807      |
# |     precision     |       0.9729      |      0.7544      |
# |    sensitivity    |       0.9992      |      0.3826      |
# |    specificity    |       0.9722      |      0.9967      |
# |        auc        |       0.9857      |      0.6897      |
# +-------------------+-------------------+------------------+
# 11/06/2025-23:33:53 | Computations in outer fold 5 took 1.28034915 minutes.
# 11/06/2025-23:33:53 | Writing results to project folder...
#
# *****************************************************************************************************
# Finished all outer fold computations.
# 11/06/2025-23:34:49 | Now analysing the final results...
# 11/06/2025-23:34:49 | Computing dummy metrics...
# 11/06/2025-23:34:49 | Computing mean and std for all outer fold metrics...
# 11/06/2025-23:34:49 | Find best config across outer folds...
# 11/06/2025-23:34:49 | Save final results...
# 11/06/2025-23:34:49 | Writing results to project folder...
# 11/06/2025-23:35:48 | Prepare Hyperpipe.optimum pipe with best config..
# 11/06/2025-23:35:48 | Fitting best model...
# 11/06/2025-23:36:23 | Saved best model to file.
# 11/06/2025-23:36:23 | Summarizing results...
# 11/06/2025-23:36:23 | Write predictions to files...
# 11/06/2025-23:36:24 | Write summary...
# *****************************************************************************************************
#
# ANALYSIS INFORMATION ================================================================================
# Project Folder: ./analysis/participant2_15s\5FinalPipelineCIGB_results_2025-06-11_22-58-47,
# Computation Time: 2025-06-11 22:58:47.233079 - 2025-06-11 23:34:49.040869
# Duration: 0:36:01.807790
# Optimized for: balanced_accuracy
# Hyperparameter Optimizer: sk_opt
#
# DUMMY RESULTS =======================================================================================
# +-------------------+--------+
# | PERFORMANCE DUMMY |        |
# +-------------------+--------+
# | balanced_accuracy | 0.5000 |
# |      f1_score     | 0.0000 |
# |      accuracy     | 0.9740 |
# |     precision     | 0.0000 |
# |    sensitivity    | 0.0000 |
# |    specificity    | 1.0000 |
# |        auc        | 0.5000 |
# +-------------------+--------+
#
# AVERAGE PERFORMANCE ACROSS OUTER FOLDS ==============================================================
# +-------------------+---------------+--------------+-----------+----------+
# |    Metric Name    | Training Mean | Training Std | Test Mean | Test Std |
# +-------------------+---------------+--------------+-----------+----------+
# | balanced_accuracy |    0.973473   |   0.022865   |  0.778802 | 0.15452  |
# |      f1_score     |    0.974583   |   0.021171   |  0.449487 | 0.316431 |
# |      accuracy     |    0.973473   |   0.022865   |  0.785388 | 0.323599 |
# |     precision     |    0.953354   |   0.039945   |  0.468762 | 0.366789 |
# |    sensitivity    |    0.99772    |   0.001683   |  0.771852 | 0.275694 |
# |    specificity    |    0.949226   |   0.046207   |  0.785752 | 0.335878 |
# |        auc        |    0.973473   |   0.022865   |  0.778802 | 0.15452  |
# +-------------------+---------------+--------------+-----------+----------+
#
# BEST HYPERPARAMETER CONFIGURATION ===================================================================
# {
#     "GradientBoostingClassifier": [
#         "loss=exponential",
#         "learning_rate=0.006301171989311478"
#     ],
#     "ImbalancedDataTransformer": [
#         "method_name=BorderlineSMOTE"
#     ]
# }
#
#
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | fold # | balanced_accuracy | f1_score | accuracy | precision | sensitivity | specificity |  auc   |                                                                 Best Hyperparameter Config                                                                 |
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   1    |       0.5636      |  0.0576  |  0.1499  |   0.0297  |    1.0000   |    0.1273   | 0.5636 |  {'ImbalancedDataTransformer': ['method_name=BorderlineSMOTE'], 'GradientBoostingClassifier': ['loss=exponential', 'learning_rate=0.009536616020457607']}  |
# |   2    |       0.9106      |  0.2306  |  0.8268  |   0.1304  |    0.9989   |    0.8222   | 0.9106 | {'ImbalancedDataTransformer': ['method_name=RandomUnderSampler'], 'GradientBoostingClassifier': ['loss=exponential', 'learning_rate=0.09885802353002207']} |
# |   3*   |       0.9933      |  0.9933  |  0.9997  |   1.0000  |    0.9866   |    1.0000   | 0.9933 |  {'ImbalancedDataTransformer': ['method_name=BorderlineSMOTE'], 'GradientBoostingClassifier': ['loss=exponential', 'learning_rate=0.006301171989311478']}  |
# |   4    |       0.7368      |  0.4582  |  0.9698  |   0.4294  |    0.4911   |    0.9826   | 0.7368 |        {'ImbalancedDataTransformer': ['method_name=SMOTE'], 'GradientBoostingClassifier': ['loss=exponential', 'learning_rate=0.2182599387759227']}        |
# |   5    |       0.6897      |  0.5077  |  0.9807  |   0.7544  |    0.3826   |    0.9967   | 0.6897 | {'ImbalancedDataTransformer': ['method_name=RandomUnderSampler'], 'GradientBoostingClassifier': ['loss=exponential', 'learning_rate=0.5385232668929524']}  |
# +--------+-------------------+----------+----------+-----------+-------------+-------------+--------+------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# PHOTONAI 2.5.0 ======================================================================================
# Your results are stored in ./analysis/participant2_15s\5FinalPipelineCIGB_results_2025-06-11_22-58-47
# Go to https://explorer.photon-ai.com and upload your photonai_results.json for convenient result visualization!
# For more info and documentation visit https://www.photon-ai.com

# %%
# Alternative 1: Built-in Feature Importances (Fastest)
print("Method 1: Built-in GradientBoosting Feature Importances")
print("-" * 55)
try:
    # Get the trained estimator
    gb_estimator = final_pipeline1.optimum_pipe.named_steps['GradientBoostingClassifier']
    
    if hasattr(gb_estimator, 'feature_importances_'):
        importances = gb_estimator.feature_importances_
        feature_names = np.array(columns[1:-1])
        
        # Sort by importance
        indices = np.argsort(importances)[::-1]
        
        for i, idx in enumerate(indices):
            print(f"{feature_names[idx]:<20} {importances[idx]:.4f}")
    else:
        print("Built-in feature importances not available")
        
except Exception as e:
    print(f"Error: {e}")

print("\n" + "="*60 + "\n")
# Out:
# Method 1: Built-in GradientBoosting Feature Importances
# -------------------------------------------------------
# time_from_last_drug_taken 0.9600
# steps                0.0399
# nonrem_percentage    0.0000
# light                0.0000
# heart_rate           0.0000
# sleep_efficiency     0.0000
# total                0.0000
# nonrem_total         0.0000
# deep                 0.0000
# rem                  0.0000
# stress_score         0.0000
# awake                0.0000
#
# ============================================================

# %%
# Alternative 2: Using sklearn's permutation_importance directly
print("Method 2: Sklearn Permutation Importance")
print("-" * 40)
try:
    from sklearn.inspection import permutation_importance
    
    # Get the fitted pipeline
    fitted_pipeline = final_pipeline1.optimum_pipe
    
    # Use a subset of data for faster computation (optional)
    # X_sample = X.sample(n=min(1000, len(X)), random_state=42)
    # y_sample = y.loc[X_sample.index]
    
    # Calculate permutation importance
    perm_importance = permutation_importance(
        fitted_pipeline, X, y, 
        n_repeats=10,  # Reduced for speed
        random_state=42,
        scoring='balanced_accuracy'
    )
    
    feature_names = np.array(columns[1:-1])
    
    # Sort by importance
    indices = np.argsort(perm_importance.importances_mean)[::-1]
    
    for i, idx in enumerate(indices):
        print(f"{feature_names[idx]:<20} {perm_importance.importances_mean[idx]:.4f} "
              f"±{perm_importance.importances_std[idx]:.4f}")
        
except Exception as e:
    print(f"Error: {e}")

print("\n" + "="*60 + "\n")
# Out:
# Method 2: Sklearn Permutation Importance
# ----------------------------------------
# Error: 'PhotonPipeline' object has no attribute 'classes_'
#
# ============================================================

# %%
# Alternative 3: SHAP Values (if you have shap installed)
print("Method 3: SHAP Feature Importance")
print("-" * 35)
try:
    import shap
    
    # Get the fitted pipeline
    fitted_pipeline = final_pipeline1.optimum_pipe
    
    # Use a sample for SHAP (it can be slow on large datasets)
    X_sample = X.sample(n=min(500, len(X)), random_state=42)
    
    # Create explainer
    explainer = shap.Explainer(fitted_pipeline, X_sample)
    shap_values = explainer(X_sample)
    
    # Get mean absolute SHAP values as feature importance
    feature_importance = np.abs(shap_values.values).mean(0)
    feature_names = np.array(columns[1:-1])
    
    # Sort by importance
    indices = np.argsort(feature_importance)[::-1]
    
    for i, idx in enumerate(indices):
        print(f"{feature_names[idx]:<20} {feature_importance[idx]:.4f}")
        
except ImportError:
    print("SHAP not installed. Install with: pip install shap")
except Exception as e:
    print(f"Error: {e}")

print("\n" + "="*60 + "\n")
# Out:
# Method 3: SHAP Feature Importance
# -----------------------------------
# Error: The passed model is not callable and cannot be analyzed directly with the given masker! Model: PhotonPipeline(elements=[('ImbalancedDataTransformer',
#                           PipelineElement(config=None,
#                                           method_name='BorderlineSMOTE',
#                                           name='ImbalancedDataTransformer')),
#                          ('GradientBoostingClassifier',
#                           PipelineElement(ccp_alpha=0.0,
#                                           criterion='friedman_mse', init=None,
#                                           learning_rate=0.006301171989311478,
#                                           loss='exponential', max_depth=3,
#                                           max_features=None,
#                                           max_leaf_nodes=None,
#                                           min_impurity_decrease=0.0,
#                                           min_samples_leaf=1,
#                                           min_samples_split=2,
#                                           min_weight_fraction_leaf=0.0,
#                                           n_estimators=100,
#                                           n_iter_no_change=None,
#                                           name='GradientBoostingClassifier',
#                                           random_state=4, subsample=1.0,
#                                           tol=0.0001, validation_fraction=0.1,
#                                           verbose=0, warm_start=False))])
#
# ============================================================

# %%
# Alternative 4: Simple DataFrame approach for better visualization
print("Method 4: DataFrame Summary")
print("-" * 25)
try:
    import pandas as pd
    
    # Using the original hyperpipe method but organizing results better
    r = final_pipeline1.get_permutation_feature_importances(
        n_repeats=20,  # Reduced for speed
        random_state=0, 
        scoring='balanced_accuracy'
    )
    
    # Create DataFrame for better organization
    importance_df = pd.DataFrame({
        'Feature': np.array(columns[1:-1]),
        'Importance': r["mean"],
        'Std_Dev': r["std"],
        'Lower_Bound': r["mean"] - 2 * r["std"],
        'Upper_Bound': r["mean"] + 2 * r["std"]
    })
    
    # Sort by importance
    importance_df = importance_df.sort_values('Importance', ascending=False)
    
    # Display top 10
    print("Top 10 Most Important Features:")
    print(importance_df.head(10).to_string(index=False, float_format='%.4f'))
    
    # Show only statistically significant features
    significant_features = importance_df[importance_df['Lower_Bound'] > 0]
    
    if len(significant_features) > 0:
        print(f"\nStatistically Significant Features ({len(significant_features)}):")
        print(significant_features.to_string(index=False, float_format='%.4f'))
    else:
        print("\nNo statistically significant features found")
        
except Exception as e:
    print(f"Error: {e}")

print("\n" + "="*60 + "\n")
# Out:
# Method 4: DataFrame Summary
# -------------------------
#
# Computing permutation importances. This may take a while.
# *****************************************************************************************************
# Permutation Importances: Fitting model for outer fold 1
# Permutation Importances: Calculating performances for outer fold 1
# Error: 'PhotonPipeline' object has no attribute 'classes_'
#
# ============================================================

# %%
# Alternative 5: Quick and Simple (Minimal Code)
print("Method 5: Quick and Simple")
print("-" * 25)
try:
    # Just get the built-in importances with minimal code
    estimator = final_pipeline1.optimum_pipe.named_steps['GradientBoostingClassifier']
    importances = estimator.feature_importances_
    features = np.array(columns[1:-1])
    
    # Create sorted list of (importance, feature) tuples
    sorted_features = sorted(zip(importances, features), reverse=True)
    
    print("Feature Importance Ranking:")
    for i, (importance, feature) in enumerate(sorted_features[:15], 1):
        print(f"{i:2d}. {feature:<20} {importance:.4f}")
        
except Exception as e:
    print(f"Error: {e}")
# Out:
# Method 5: Quick and Simple
# -------------------------
# Feature Importance Ranking:
#  1. time_from_last_drug_taken 0.9585
#  2. steps                0.0376
#  3. total                0.0008
#  4. heart_rate           0.0006
#  5. light                0.0006
#  6. nonrem_percentage    0.0006
#  7. nonrem_total         0.0004
#  8. awake                0.0003
#  9. rem                  0.0003
# 10. sleep_efficiency     0.0002
# 11. deep                 0.0001
# 12. stress_score         0.0000
